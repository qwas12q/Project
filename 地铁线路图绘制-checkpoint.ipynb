# %%
import requests
import time

null = None #将json中的null定义为None
city_code = 289 #上海的城市编号
station_info = requests.get('http://map.baidu.com/?qt=bsi&c=%s&t=%s' % (
                    city_code, 
                    int(time.time() * 1000)
               )
)
station_info_json = eval(station_info.content) #将json字符串转为python对象
for railway in station_info_json['content']:
    uid = railway['line_uid']
    railway_json = requests.get(
        'https://map.baidu.com/?qt=bsl&tps=&newmap=1&uid=%s&c=%s' % (uid, city_code)
    )
    railway_json = eval(railway_json.content) #将json字符串转为python对象

# %%
station_info_json
# Out:
# {'content': [{'line_name': '地铁5号线(莘庄-奉贤新城)',
#    'line_uid': '79a751e5feec0b5cfea77805',
#    'pair_line_uid': '498e9f80a57a3a5f1894c6f0',
#    'stops': [{'is_practical': 0,
#      'name': '莘庄',
#      'uid': 'e4652c92ed05c154f4e73b59',
#      'x': 13513400.74,
#      'y': 3625614.49},
#     {'is_practical': 0,
#      'name': '春申路',
#      'uid': '574d2204f53934d18e7727df',
#      'x': 13513479.61,
#      'y': 3623981.45},
#     {'is_practical': 1,
#      'name': '银都路',
#      'uid': 'd7503b102561e1b8471a32c4',
#      'x': 13513985,
#      'y': 3622833.3},
#     {'is_practical': 0,
#      'name': '颛桥',
#      'uid': '090123157a56fae73de2311a',
#      'x': 13515272.27,
#      'y': 3619956.77},
#     {'is_practical': 0,
#      'name': '北桥',
#      'uid': 'd6c145dda1ae8d8831870aa3',
#      'x': 13516168.4,
#      'y': 3617149.63},
#     {'is_practical': 0,
#      'name': '剑川路',
#      'uid': 'e885d520f7b8c394e507389d',
#      'x': 13516890.6,
#      'y': 3614749.98},
#     {'is_practical': 0,
#      'name': '东川路',
#      'uid': 'ced7fa669ada7a9803ec012b',
#      'x': 13517276.96,
#      'y': 3613662.02},
#     {'is_practical': 0,
#      'name': '江川路',
#      'uid': '1b68c8bab5037a9170210b34',
#      'x': 13517660.85,
#      'y': 3612056.96},
#     {'is_practical': 0,
#      'name': '西渡',
#      'uid': '3308e93b906341148b2fb5fc',
#      'x': 13518664.9,
#      'y': 3609973.96},
#     {'is_practical': 1,
#      'name': '萧塘',
#      'uid': 'e5f4405adc51a285b04c4941',
#      'x': 13519720.88,
#      'y': 3606956.8},
#     {'is_practical': 1,
#      'name': '奉浦大道',
#      'uid': '07465c3027ef162b3fe2312c',
#      'x': 13520535.82,
#      'y': 3603837.73},
#     {'is_practical': 1,
#      'name': '环城东路',
#      'uid': '59e13ff20fdd57c5e8f853d5',
#      'x': 13522134.83,
#      'y': 3602419.66},
#     {'is_practical': 0,
#      'name': '望园路',
#      'uid': 'e9080e89384dabd3c909f0c7',
#      'x': 13524384.82,
#      'y': 3602493.84},
#     {'is_practical': 0,
#      'name': '金海湖',
#      'uid': '1c069eb70c0ba58a0869d935',
#      'x': 13525358.9,
#      'y': 3602092.85},
#     {'is_practical': 0,
#      'name': '奉贤新城',
#      'uid': 'a610da94039b872142ab9af3',
#      'x': 13525772.84,
#      'y': 3600184.89}]},
#   {'line_name': '轨道交通浦江线(沈杜公路-汇臻路)',
#    'line_uid': 'dad6fd43605318301ce999f0',
#    'pair_line_uid': '92cb003116315e68b817e788',
#    'stops': [{'is_practical': 1,
#      'name': '沈杜公路',
#      'uid': 'ded0d57cc6ccd1273517dcce',
#      'x': 13527567.82,
#      'y': 3619208.73},
#     {'is_practical': 1,
#      'name': '三鲁公路',
#      'uid': 'a8b00544cfb1152ffa42b23f',
#      'x': 13529190.67,
#      'y': 3618558.73},
#     {'is_practical': 1,
#      'name': '闵瑞路',
#      'uid': '84db0925baca8b2b077ce821',
#      'x': 13529569.91,
#      'y': 3617580.82},
#     {'is_practical': 0,
#      'name': '浦航路',
#      'uid': 'a74b54df5bf55f325b109376',
#      'x': 13529594.23,
#      'y': 3616620.46},
#     {'is_practical': 1,
#      'name': '东城一路',
#      'uid': '8091b8ec35f75a2714c8f6b7',
#      'x': 13529779.9,
#      'y': 3615194.9},
#     {'is_practical': 1,
#      'name': '汇臻路',
#      'uid': 'b1fc0acfbf3d4222b8bd633b',
#      'x': 13528959.92,
#      'y': 3614567.81}]},
#   {'line_name': '地铁5号线(奉贤新城-莘庄)',
#    'line_uid': '498e9f80a57a3a5f1894c6f0',
#    'pair_line_uid': '79a751e5feec0b5cfea77805',
#    'stops': [{'is_practical': 1,
#      'name': '奉贤新城',
#      'uid': 'd320ba5eade5685004fef5bc',
#      'x': 13525772.84,
#      'y': 3600184.89},
#     {'is_practical': 1,
#      'name': '金海湖',
#      'uid': 'a9ae8d33ccf3824b03ec0121',
#      'x': 13525358.9,
#      'y': 3602092.85},
#     {'is_practical': 1,
#      'name': '望园路',
#      'uid': '4a51aaf7b42c4a3c3913fdfa',
#      'x': 13524384.82,
#      'y': 3602493.84},
#     {'is_practical': 0,
#      'name': '环城东路',
#      'uid': '9d733b3e1478fbaa29fc48dc',
#      'x': 13522134.83,
#      'y': 3602419.66},
#     {'is_practical': 0,
#      'name': '奉浦大道',
#      'uid': 'e8dfe7114240f11bca2915a1',
#      'x': 13520535.82,
#      'y': 3603837.73},
#     {'is_practical': 0,
#      'name': '萧塘',
#      'uid': '8d97c58ea253c15746e274ba',
#      'x': 13519720.88,
#      'y': 3606956.8},
#     {'is_practical': 1,
#      'name': '西渡',
#      'uid': '3ac838f79d16e934ca09f0d1',
#      'x': 13518664.9,
#      'y': 3609973.96},
#     {'is_practical': 1,
#      'name': '江川路',
#      'uid': '1b1b96facda85c269d95de0a',
#      'x': 13517660.85,
#      'y': 3612056.96},
#     {'is_practical': 1,
#      'name': '东川路',
#      'uid': '31b6aeefc10b565fb1077d9f',
#      'x': 13517276.96,
#      'y': 3613662.02},
#     {'is_practical': 1,
#      'name': '剑川路',
#      'uid': '425f32f3a0916bba4d776e81',
#      'x': 13516890.6,
#      'y': 3614749.98},
#     {'is_practical': 1,
#      'name': '北桥',
#      'uid': '74843fe7a8a3e9fa7adbd253',
#      'x': 13516168.4,
#      'y': 3617149.63},
#     {'is_practical': 0,
#      'name': '颛桥',
#      'uid': '32b7281b99b5a26632870a36',
#      'x': 13515272.27,
#      'y': 3619956.77},
#     {'is_practical': 0,
#      'name': '银都路',
#      'uid': 'd6b14f40ad5e5f27734b8785',
#      'x': 13513985,
#      'y': 3622833.3},
#     {'is_practical': 1,
#      'name': '春申路',
#      'uid': '1f595b6383282ef6cb213d37',
#      'x': 13513479.61,
#      'y': 3623981.45},
#     {'is_practical': 1,
#      'name': '莘庄',
#      'uid': '480c789657a7fe38f32d832a',
#      'x': 13513400.74,
#      'y': 3625614.49}]},
#   {'line_name': '地铁8号线(市光路-沈杜公路)',
#    'line_uid': '2d6cc6ff85250abeb75f1eb7',
#    'pair_line_uid': '453b2d228cf08f16d4851fb7',
#    'stops': [{'is_practical': 1,
#      'name': '市光路',
#      'uid': '329d192994fb88054acc4ad9',
#      'x': 13529754.13,
#      'y': 3653066.38},
#     {'is_practical': 1,
#      'name': '嫩江路',
#      'uid': 'e60332fc0e4b738515b54bd9',
#      'x': 13529757.66,
#      'y': 3652081.81},
#     {'is_practical': 1,
#      'name': '翔殷路',
#      'uid': 'ccd6a84cf5cb2cfcc23644d9',
#      'x': 13529748,
#      'y': 3650798.3},
#     {'is_practical': 1,
#      'name': '黄兴公园',
#      'uid': '596653ccaab2fb7f410245d9',
#      'x': 13529882.18,
#      'y': 3649619.8},
#     {'is_practical': 1,
#      'name': '延吉中路',
#      'uid': 'a3e60cb57d31784b4d6d46d9',
#      'x': 13530074.5,
#      'y': 3648685.19},
#     {'is_practical': 1,
#      'name': '黄兴路',
#      'uid': '8307eec51502eabd293a9fde',
#      'x': 13529299.28,
#      'y': 3647369.34},
#     {'is_practical': 1,
#      'name': '江浦路',
#      'uid': 'e4eeb3056cf31073266e98de',
#      'x': 13528226.46,
#      'y': 3646882.62},
#     {'is_practical': 1,
#      'name': '鞍山新村',
#      'uid': 'be2ecaf4963d1f271ee999de',
#      'x': 13527253.79,
#      'y': 3646636.95},
#     {'is_practical': 1,
#      'name': '四平路',
#      'uid': 'c6df303a996927a041ab9ade',
#      'x': 13526336.3,
#      'y': 3646850.37},
#     {'is_practical': 1,
#      'name': '曲阳路',
#      'uid': '3f113f6ea1ee78e232169bde',
#      'x': 13525135.68,
#      'y': 3647051.65},
#     {'is_practical': 0,
#      'name': '虹口足球场',
#      'uid': '314507e9feac0b5f1d3894de',
#      'x': 13523902.68,
#      'y': 3646229.9},
#     {'is_practical': 1,
#      'name': '西藏北路',
#      'uid': '06c258ab8d112471cb1b95de',
#      'x': 13522710.11,
#      'y': 3645402.83},
#     {'is_practical': 1,
#      'name': '中兴路',
#      'uid': '58802b16a23ff2527af796de',
#      'x': 13522728.07,
#      'y': 3644059.74},
#     {'is_practical': 0,
#      'name': '曲阜路',
#      'uid': '283d0438741c43beea1e97de',
#      'x': 13523018.05,
#      'y': 3642664.79},
#     {'is_practical': 0,
#      'name': '人民广场',
#      'uid': '0613d21bc5f0d35717a190de',
#      'x': 13523472.35,
#      'y': 3641424.11},
#     {'is_practical': 1,
#      'name': '大世界',
#      'uid': 'd73063f755192ee8dad891de',
#      'x': 13523894.02,
#      'y': 3640703.1},
#     {'is_practical': 1,
#      'name': '老西门',
#      'uid': '67dcf31ea8a6e39141e192de',
#      'x': 13524294.74,
#      'y': 3639608.04},
#     {'is_practical': 1,
#      'name': '陆家浜路',
#      'uid': 'f4350ea165df78a85a1093de',
#      'x': 13524656.1,
#      'y': 3638661.99},
#     {'is_practical': 0,
#      'name': '西藏南路',
#      'uid': '088ac3d8fee6635997f08cde',
#      'x': 13525030.64,
#      'y': 3637412.98},
#     {'is_practical': 1,
#      'name': '中华艺术宫',
#      'uid': 'f7047f3d77c431e11911d51d',
#      'x': 13525496.84,
#      'y': 3635238.43},
#     {'is_practical': 1,
#      'name': '耀华路',
#      'uid': 'faf358e1e517aeb948fc8dde',
#      'x': 13525589.33,
#      'y': 3634358.85},
#     {'is_practical': 0,
#      'name': '成山路',
#      'uid': '783bcc2c6c3b0e5e09ccdd28',
#      'x': 13525769.23,
#      'y': 3633366.7},
#     {'is_practical': 1,
#      'name': '杨思',
#      'uid': '81052e17b6cba6dc4f2fdf28',
#      'x': 13525497.6,
#      'y': 3632102.03},
#     {'is_practical': 0,
#      'name': '东方体育中心',
#      'uid': 'ec19e04f09219f8eaf04570f',
#      'x': 13524019.46,
#      'y': 3631149.5},
#     {'is_practical': 1,
#      'name': '凌兆新村',
#      'uid': '5df58695f02890440969d928',
#      'x': 13525051.04,
#      'y': 3629511.5},
#     {'is_practical': 0,
#      'name': '芦恒路',
#      'uid': 'fe341069b33af18a08a8d428',
#      'x': 13525952.5,
#      'y': 3626691.83},
#     {'is_practical': 1,
#      'name': '浦江镇',
#      'uid': '5150153d77c431e11911d528',
#      'x': 13526900.28,
#      'y': 3623753.62},
#     {'is_practical': 1,
#      'name': '江月路',
#      'uid': '92fa11a8a616e9644154d728',
#      'x': 13527149.91,
#      'y': 3622174.35},
#     {'is_practical': 0,
#      'name': '联航路',
#      'uid': '8d1458549b0c105878dbd228',
#      'x': 13527372.25,
#      'y': 3620837.83},
#     {'is_practical': 0,
#      'name': '沈杜公路',
#      'uid': '7b323011c7dc4b206da3cc28',
#      'x': 13527559.4,
#      'y': 3619208.44}]},
#   {'line_name': '地铁13号线(金运路-张江路)',
#    'line_uid': 'e226f1493252e3a58b36eecd',
#    'pair_line_uid': '8cb221172f25114bd52ce2cd',
#    'stops': [{'is_practical': 1,
#      'name': '金运路',
#      'uid': 'aa54155565ebb27fcc04efcd',
#      'x': 13506099.44,
#      'y': 3642547.96},
#     {'is_practical': 1,
#      'name': '金沙江西路',
#      'uid': '494842ec3431f54d057ce8cd',
#      'x': 13507842.2,
#      'y': 3642552.01},
#     {'is_practical': 1,
#      'name': '丰庄',
#      'uid': '1ff1133673033c35a31de9cd',
#      'x': 13510123.37,
#      'y': 3642677.52},
#     {'is_practical': 1,
#      'name': '祁连山南路',
#      'uid': '234b24a23a128501177643cd',
#      'x': 13511454.76,
#      'y': 3642004.08},
#     {'is_practical': 1,
#      'name': '真北路',
#      'uid': '4d2b5404ba7b9a549c82eacd',
#      'x': 13513096.13,
#      'y': 3641316.29},
#     {'is_practical': 0,
#      'name': '大渡河路',
#      'uid': 'a3cf64a2adb37d159e82eada',
#      'x': 13514523.26,
#      'y': 3641274.02},
#     {'is_practical': 0,
#      'name': '金沙江路',
#      'uid': '0b199d7c1c1aa5cb09f5ebcd',
#      'x': 13516448.08,
#      'y': 3641234.13},
#     {'is_practical': 1,
#      'name': '隆德路',
#      'uid': 'e4637199a68f8eb8871541e8',
#      'x': 13517644.29,
#      'y': 3641166.03},
#     {'is_practical': 0,
#      'name': '武宁路',
#      'uid': 'af89910ff0217e2e343a710f',
#      'x': 13518415.95,
#      'y': 3641631.11},
#     {'is_practical': 0,
#      'name': '长寿路',
#      'uid': '74605ef90c9b9dee5e17c38f',
#      'x': 13519318.81,
#      'y': 3642523.51},
#     {'is_practical': 0,
#      'name': '江宁路',
#      'uid': '524077e96793f3e2ae080f11',
#      'x': 13519962.58,
#      'y': 3642960.55},
#     {'is_practical': 0,
#      'name': '汉中路',
#      'uid': 'c7f814025adb4f6c0aa8d454',
#      'x': 13521615.25,
#      'y': 3642475.04},
#     {'is_practical': 0,
#      'name': '自然博物馆',
#      'uid': 'b594e217555ec88b601809e2',
#      'x': 13522045.42,
#      'y': 3641841.72},
#     {'is_practical': 1,
#      'name': '南京西路',
#      'uid': '6da1f6b6c9f0bc14df1e52b1',
#      'x': 13522008.71,
#      'y': 3640899.7},
#     {'is_practical': 1,
#      'name': '淮海中路',
#      'uid': '766754f347bb36a894031995',
#      'x': 13522201.03,
#      'y': 3639805.36},
#     {'is_practical': 1,
#      'name': '新天地',
#      'uid': '1ffd6d33b54f9eef16c90546',
#      'x': 13523398.29,
#      'y': 3639197.4},
#     {'is_practical': 0,
#      'name': '马当路',
#      'uid': '6bf6adac7d619e0688fc0683',
#      'x': 13523564.24,
#      'y': 3638422.29},
#     {'is_practical': 1,
#      'name': '世博会博物馆',
#      'uid': '1a39193224ca609af8221308',
#      'x': 13524186.73,
#      'y': 3636749.87},
#     {'is_practical': 1,
#      'name': '世博大道',
#      'uid': '3c032c1de7b0e9b61d1d1107',
#      'x': 13524456.36,
#      'y': 3634888.3},
#     {'is_practical': 0,
#      'name': '长清路',
#      'uid': 'ac5e13ef40e3b07ae5e965d9',
#      'x': 13524943.08,
#      'y': 3633764.94},
#     {'is_practical': 0,
#      'name': '成山路',
#      'uid': '2d2d6954ca25474a246e98de',
#      'x': 13525886.89,
#      'y': 3633452.78},
#     {'is_practical': 0,
#      'name': '东明路',
#      'uid': '4fd017f1280d1f34fb2213fb',
#      'x': 13527581.96,
#      'y': 3633637.66},
#     {'is_practical': 0,
#      'name': '华鹏路',
#      'uid': '389aaf9a7e9544643b221c48',
#      'x': 13529192.92,
#      'y': 3634138.79},
#     {'is_practical': 1,
#      'name': '下南路',
#      'uid': '3a543b981fd7f8e435b06c3f',
#      'x': 13530660.88,
#      'y': 3634538.98},
#     {'is_practical': 0,
#      'name': '北蔡',
#      'uid': '17861f652662ca9e9e95de6e',
#      'x': 13532006.86,
#      'y': 3634660.01},
#     {'is_practical': 0,
#      'name': '陈春路',
#      'uid': 'fbe27c667c8f4c18220220eb',
#      'x': 13532593.88,
#      'y': 3633996},
#     {'is_practical': 0,
#      'name': '莲溪路',
#      'uid': '5a9947041b6c9525d52ce262',
#      'x': 13533541.95,
#      'y': 3633219.81},
#     {'is_practical': 0,
#      'name': '华夏中路',
#      'uid': 'd387e307576fd064c61e5193',
#      'x': 13535281.86,
#      'y': 3633897.67},
#     {'is_practical': 1,
#      'name': '中科路',
#      'uid': 'add7c8a95bad0072095cb3f3',
#      'x': 13537603.87,
#      'y': 3634424.99},
#     {'is_practical': 1,
#      'name': '学林路',
#      'uid': '7c83ff20dbe72182a11de9c5',
#      'x': 13538916.91,
#      'y': 3635001.86},
#     {'is_practical': 1,
#      'name': '张江路',
#      'uid': 'eac7159fa8698e592cb96d0d',
#      'x': 13540551.54,
#      'y': 3635757.76}]},
#   {'line_name': '地铁9号线(曹路-松江南站)',
#    'line_uid': 'a533a15f6a82e35a970319b7',
#    'pair_line_uid': 'afe624f70958ecccdb1318b7',
#    'stops': [{'is_practical': 1,
#      'name': '曹路',
#      'uid': 'c3fa11f94e41ba58047ce83b',
#      'x': 13546554.93,
#      'y': 3646459.03},
#     {'is_practical': 1,
#      'name': '民雷路',
#      'uid': '53a3f5534703ea5f14c8f67b',
#      'x': 13544902.94,
#      'y': 3646083.17},
#     {'is_practical': 0,
#      'name': '顾唐路',
#      'uid': '53a96f9c6ae2895014c8f624',
#      'x': 13543610.62,
#      'y': 3645764.14},
#     {'is_practical': 0,
#      'name': '金海路',
#      'uid': '3c00c4aedac1fc83b64f543b',
#      'x': 13541658.11,
#      'y': 3645414.67},
#     {'is_practical': 1,
#      'name': '金吉路',
#      'uid': '5badcb8d675b534d3c9a5e28',
#      'x': 13540426.87,
#      'y': 3645472.84},
#     {'is_practical': 1,
#      'name': '金桥',
#      'uid': '747dce97aaddeaabfbdc8500',
#      'x': 13538719.61,
#      'y': 3645077.39},
#     {'is_practical': 0,
#      'name': '台儿庄路',
#      'uid': '405cdc2773416f753a13fd8d',
#      'x': 13537040.85,
#      'y': 3644016.95},
#     {'is_practical': 1,
#      'name': '蓝天路',
#      'uid': '4c22b3926b9e45305bf6be2c',
#      'x': 13534834.94,
#      'y': 3642567.77},
#     {'is_practical': 0,
#      'name': '芳甸路',
#      'uid': '892d98f487a9282e223bf246',
#      'x': 13532658.84,
#      'y': 3641295.91},
#     {'is_practical': 0,
#      'name': '杨高中路',
#      'uid': '848c32ece30ad8582bb97c87',
#      'x': 13531590.35,
#      'y': 3640789.03},
#     {'is_practical': 0,
#      'name': '世纪大道',
#      'uid': 'b877d321ffd171b4e4073847',
#      'x': 13529184.46,
#      'y': 3640921.24},
#     {'is_practical': 1,
#      'name': '商城路',
#      'uid': 'beb559d6f7fadd4ea4da3947',
#      'x': 13528013.38,
#      'y': 3641091.43},
#     {'is_practical': 1,
#      'name': '小南门',
#      'uid': '354251fd5b009d930bb93a47',
#      'x': 13526010.17,
#      'y': 3639346.55},
#     {'is_practical': 0,
#      'name': '陆家浜路',
#      'uid': '3e69fd071bdd32f0f6e73b47',
#      'x': 13524647.2,
#      'y': 3638666.42},
#     {'is_practical': 1,
#      'name': '马当路',
#      'uid': '9393bddab4becfaea3a93447',
#      'x': 13523650.56,
#      'y': 3638380.04},
#     {'is_practical': 1,
#      'name': '打浦桥',
#      'uid': 'dc4e12b949e09ae012293547',
#      'x': 13522726.98,
#      'y': 3637975.92},
#     {'is_practical': 1,
#      'name': '嘉善路',
#      'uid': '722defe71cae2b60b31e3647',
#      'x': 13521816.11,
#      'y': 3637570.62},
#     {'is_practical': 0,
#      'name': '肇嘉浜路',
#      'uid': '8c73baa9ad2e8a57f3193747',
#      'x': 13520593.61,
#      'y': 3637158.59},
#     {'is_practical': 0,
#      'name': '徐家汇',
#      'uid': 'd83d0b290c19ca50a3d23047',
#      'x': 13519155.58,
#      'y': 3636662.84},
#     {'is_practical': 0,
#      'name': '宜山路',
#      'uid': '93dbb8acefe223dd0a1cc7de',
#      'x': 13518128.85,
#      'y': 3635270.56},
#     {'is_practical': 0,
#      'name': '桂林路',
#      'uid': 'ca8749e5a59333554351c0de',
#      'x': 13517114.22,
#      'y': 3633952.26},
#     {'is_practical': 0,
#      'name': '漕河泾开发区',
#      'uid': '3cce0394b51b7a184007c1de',
#      'x': 13514796.77,
#      'y': 3633333.22},
#     {'is_practical': 0,
#      'name': '合川路',
#      'uid': '77bf131cfc56794e0582c2de',
#      'x': 13513350.13,
#      'y': 3632816.08},
#     {'is_practical': 0,
#      'name': '星中路',
#      'uid': '64375a51ff003ccb5c17c3de',
#      'x': 13511613.74,
#      'y': 3631733.46},
#     {'is_practical': 0,
#      'name': '七宝',
#      'uid': '2c7a5907ba85655ecbe33cde',
#      'x': 13509440.57,
#      'y': 3631413.78},
#     {'is_practical': 0,
#      'name': '中春路',
#      'uid': '302c1c82e310f2aaca213dde',
#      'x': 13508181.96,
#      'y': 3630709.73},
#     {'is_practical': 0,
#      'name': '九亭',
#      'uid': '74a9451774e4f36840d63ede',
#      'x': 13506026.3,
#      'y': 3629142.38},
#     {'is_practical': 0,
#      'name': '泗泾',
#      'uid': '2e3cd2e37526799f48fd3fde',
#      'x': 13499556.36,
#      'y': 3626571.26},
#     {'is_practical': 0,
#      'name': '佘山',
#      'uid': 'b8c8d321ffd171b4e40738de',
#      'x': 13496105.22,
#      'y': 3624841.86},
#     {'is_practical': 0,
#      'name': '洞泾',
#      'uid': 'be0a59d6f7fadd4ea4da39de',
#      'x': 13496189.54,
#      'y': 3622226.66},
#     {'is_practical': 0,
#      'name': '松江大学城',
#      'uid': '35fd51fd5b009d930bb93ade',
#      'x': 13496433,
#      'y': 3618301.29},
#     {'is_practical': 0,
#      'name': '松江新城',
#      'uid': '3ed6fd071bdd32f0f6e73bde',
#      'x': 13496216.79,
#      'y': 3615220.17},
#     {'is_practical': 1,
#      'name': '松江体育中心',
#      'uid': 'cd613b1d238530bcea12e4cd',
#      'x': 13496197.88,
#      'y': 3613389.69},
#     {'is_practical': 1,
#      'name': '醉白池',
#      'uid': '6a000482b6f2d35bac31e5cd',
#      'x': 13496057.65,
#      'y': 3611443.15},
#     {'is_practical': 1,
#      'name': '松江南站',
#      'uid': '569f91f55515957842afe6cd',
#      'x': 13496229.41,
#      'y': 3609376.99}]},
#   {'line_name': '地铁1号线(莘庄-富锦路)',
#    'line_uid': '52ebbdf710b5a7a5118824b7',
#    'pair_line_uid': '3f30cc2f15f096fb9fec2bb7',
#    'stops': [{'is_practical': 0,
#      'name': '莘庄',
#      'uid': '343aa820df4728442ad7abd9',
#      'x': 13513400.74,
#      'y': 3625614.49},
#     {'is_practical': 0,
#      'name': '外环路',
#      'uid': 'b60a7940ae0a139ece06a4d9',
#      'x': 13514290.78,
#      'y': 3626917.96},
#     {'is_practical': 0,
#      'name': '莲花路',
#      'uid': '686a080d95d0f74fefe4a5d9',
#      'x': 13515372.3,
#      'y': 3628222.27},
#     {'is_practical': 0,
#      'name': '锦江乐园',
#      'uid': '182733d77101d6ad39e4a6d9',
#      'x': 13516635.39,
#      'y': 3629720.63},
#     {'is_practical': 0,
#      'name': '上海南站',
#      'uid': '20fdd70650e300ad2cfaa7d9',
#      'x': 13518368.54,
#      'y': 3631388.35},
#     {'is_practical': 0,
#      'name': '漕宝路',
#      'uid': 'c52cf6e486e315b324e0a0d9',
#      'x': 13518971.87,
#      'y': 3633108},
#     {'is_practical': 0,
#      'name': '上海体育馆',
#      'uid': 'e3ce20e493fd1da9c62ba1d9',
#      'x': 13519101.32,
#      'y': 3634904.04},
#     {'is_practical': 0,
#      'name': '徐家汇',
#      'uid': '34ce35fa9be7ff62c07da2d9',
#      'x': 13519314.04,
#      'y': 3636301.58},
#     {'is_practical': 0,
#      'name': '衡山路',
#      'uid': '22d03de0792cf934912ca3d9',
#      'x': 13520251.08,
#      'y': 3637880.34},
#     {'is_practical': 0,
#      'name': '常熟路',
#      'uid': '2bcadf2b7f7aa865f7c59cd9',
#      'x': 13520759.48,
#      'y': 3638993.65},
#     {'is_practical': 0,
#      'name': '陕西南路',
#      'uid': 'd601d97d2e2bce8caa059dd9',
#      'x': 13521755.27,
#      'y': 3639455.27},
#     {'is_practical': 0,
#      'name': '黄陂南路',
#      'uid': 'd157882c48c2934cd3f49ed9',
#      'x': 13523216.39,
#      'y': 3640136.36},
#     {'is_practical': 0,
#      'name': '人民广场',
#      'uid': '8306eec51502eabd293a9fd9',
#      'x': 13523427.94,
#      'y': 3641450.87},
#     {'is_practical': 0,
#      'name': '新闸路',
#      'uid': 'e4efb3056cf31073266e98d9',
#      'x': 13522660.22,
#      'y': 3642202.16},
#     {'is_practical': 0,
#      'name': '汉中路',
#      'uid': 'be2fcaf4963d1f271ee999d9',
#      'x': 13521570.09,
#      'y': 3642617.7},
#     {'is_practical': 0,
#      'name': '上海火车站',
#      'uid': 'c6de303a996927a041ab9ad9',
#      'x': 13521276.61,
#      'y': 3643356.86},
#     {'is_practical': 0,
#      'name': '中山北路',
#      'uid': '3f103f6ea1ee78e232169bd9',
#      'x': 13521637.61,
#      'y': 3644868.24},
#     {'is_practical': 0,
#      'name': '延长路',
#      'uid': '314407e9feac0b5f1d3894d9',
#      'x': 13521223.19,
#      'y': 3646525.17},
#     {'is_practical': 0,
#      'name': '上海马戏城',
#      'uid': '06c358ab8d112471cb1b95d9',
#      'x': 13520845.8,
#      'y': 3647534.26},
#     {'is_practical': 0,
#      'name': '汶水路',
#      'uid': '58812b16a23ff2527af796d9',
#      'x': 13520629.55,
#      'y': 3649215.52},
#     {'is_practical': 0,
#      'name': '彭浦新村',
#      'uid': '283c0438741c43beea1e97d9',
#      'x': 13520466.61,
#      'y': 3651047.06},
#     {'is_practical': 0,
#      'name': '共康路',
#      'uid': '0612d21bc5f0d35717a190d9',
#      'x': 13520284.91,
#      'y': 3652656.48},
#     {'is_practical': 0,
#      'name': '通河新村',
#      'uid': 'd73163f755192ee8dad891d9',
#      'x': 13519656.24,
#      'y': 3654270.11},
#     {'is_practical': 0,
#      'name': '呼兰路',
#      'uid': '67ddf31ea8a6e39141e192d9',
#      'x': 13519251.96,
#      'y': 3655332.7},
#     {'is_practical': 0,
#      'name': '共富新村',
#      'uid': 'f4340ea165df78a85a1093d9',
#      'x': 13518837.06,
#      'y': 3657351.79},
#     {'is_practical': 0,
#      'name': '宝安公路',
#      'uid': '088bc3d8fee6635997f08cd9',
#      'x': 13518491.85,
#      'y': 3659252.4},
#     {'is_practical': 0,
#      'name': '友谊西路',
#      'uid': 'faf258e1e517aeb948fc8dd9',
#      'x': 13518155.5,
#      'y': 3660748.98},
#     {'is_practical': 0,
#      'name': '富锦路',
#      'uid': '60cb431028f771b516948ed9',
#      'x': 13517787.52,
#      'y': 3662168.82}]},
#   {'line_name': '地铁2号线(徐泾东-浦东国际机场)',
#    'line_uid': '247689ecaf8ffcb9455726b7',
#    'pair_line_uid': '2033b8b221eb29c1c4f025b7',
#    'stops': [{'is_practical': 0,
#      'name': '徐泾东',
#      'uid': '5d5b8695f02890440969d94a',
#      'x': 13504038.68,
#      'y': 3635820.76},
#     {'is_practical': 0,
#      'name': '虹桥火车站',
#      'uid': '5bfd3476e7bc47605bf6bea5',
#      'x': 13506307.67,
#      'y': 3636454.92},
#     {'is_practical': 0,
#      'name': '虹桥2号航站楼',
#      'uid': 'ca02562f160a30200c3dda4a',
#      'x': 13506837.79,
#      'y': 3636540.81},
#     {'is_practical': 0,
#      'name': '淞虹路',
#      'uid': 'c6c02113e1d36cf6ef74f8d9',
#      'x': 13510525.77,
#      'y': 3639520.51},
#     {'is_practical': 0,
#      'name': '北新泾',
#      'uid': '0c3947d4eab8d63de315f9d9',
#      'x': 13512178.04,
#      'y': 3639275.13},
#     {'is_practical': 0,
#      'name': '威宁路',
#      'uid': '6bfe4cbf5073da5cea56fad9',
#      'x': 13513628.77,
#      'y': 3639065.25},
#     {'is_practical': 0,
#      'name': '娄山关路',
#      'uid': '6395f6745c12d31fc7effbd9',
#      'x': 13515537.53,
#      'y': 3638608.58},
#     {'is_practical': 0,
#      'name': '中山公园',
#      'uid': 'd85efa155551fea63786f4d9',
#      'x': 13517056.11,
#      'y': 3639600.77},
#     {'is_practical': 0,
#      'name': '江苏路',
#      'uid': 'db3ff35678e80ecf05fef5d9',
#      'x': 13518669.1,
#      'y': 3639802.05},
#     {'is_practical': 0,
#      'name': '静安寺',
#      'uid': 'd37cdeef88813cb716c8f6d9',
#      'x': 13520200.67,
#      'y': 3640239.99},
#     {'is_practical': 0,
#      'name': '南京西路',
#      'uid': 'fdc52e86baf92f819e09f7d9',
#      'x': 13521767.22,
#      'y': 3641092.65},
#     {'is_practical': 0,
#      'name': '人民广场',
#      'uid': '0cac1cfea9cfa740cb09f0d9',
#      'x': 13523157.79,
#      'y': 3641436.7},
#     {'is_practical': 0,
#      'name': '南京东路',
#      'uid': '39d40fc8210ef240754ff1d9',
#      'x': 13524387.07,
#      'y': 3641970.56},
#     {'is_practical': 0,
#      'name': '陆家嘴',
#      'uid': '2be28709740e4c06203bf2d9',
#      'x': 13526447.63,
#      'y': 3642064.63},
#     {'is_practical': 0,
#      'name': '东昌路',
#      'uid': 'a023d209ca4819726949f3d9',
#      'x': 13527914.11,
#      'y': 3641474.09},
#     {'is_practical': 0,
#      'name': '世纪大道',
#      'uid': 'f4236c4f9f3c50008d55ecd9',
#      'x': 13529187.35,
#      'y': 3640926.2},
#     {'is_practical': 0,
#      'name': '上海科技馆',
#      'uid': '3565393bd64eb41cdaecedd9',
#      'x': 13531093.34,
#      'y': 3639709.94},
#     {'is_practical': 0,
#      'name': '世纪公园',
#      'uid': '611170493252e3a58b36eed9',
#      'x': 13531830.16,
#      'y': 3638475.82},
#     {'is_practical': 0,
#      'name': '龙阳路',
#      'uid': '2b63945565ebb27fcc04efd9',
#      'x': 13532569.07,
#      'y': 3637633.38},
#     {'is_practical': 0,
#      'name': '张江高科',
#      'uid': 'ce7fc3ec3431f54d057ce8d9',
#      'x': 13535936.21,
#      'y': 3637432.71},
#     {'is_practical': 0,
#      'name': '金科路',
#      'uid': '2b5c8709740e4c06203bf247',
#      'x': 13537549.93,
#      'y': 3637698.62},
#     {'is_practical': 1,
#      'name': '广兰路',
#      'uid': 'dc7250294abe1ab9f52310cd',
#      'x': 13539622.99,
#      'y': 3638575.58},
#     {'is_practical': 0,
#      'name': '唐镇',
#      'uid': '5d0625228cf08f16d4851fe8',
#      'x': 13543590.54,
#      'y': 3639022.37},
#     {'is_practical': 0,
#      'name': '创新中路',
#      'uid': 'b7db2cf70958ecccdb1318e8',
#      'x': 13545542.66,
#      'y': 3638974.94},
#     {'is_practical': 0,
#      'name': '华夏东路',
#      'uid': 'bd0ea95f6a82e35a970319e8',
#      'x': 13546315.03,
#      'y': 3636822.55},
#     {'is_practical': 0,
#      'name': '川沙',
#      'uid': '39a6ca856514af4a28201ae8',
#      'x': 13548230.28,
#      'y': 3635491.07},
#     {'is_practical': 0,
#      'name': '凌空路',
#      'uid': '457cc513290410696f3e1be8',
#      'x': 13551103.33,
#      'y': 3636230.34},
#     {'is_practical': 0,
#      'name': '远东大道',
#      'uid': '4bea890396275777c16c14e8',
#      'x': 13554649.21,
#      'y': 3637085.69},
#     {'is_practical': 0,
#      'name': '海天三路',
#      'uid': '04fa3620d139f925c92915e8',
#      'x': 13559220.37,
#      'y': 3633169.19},
#     {'is_practical': 0,
#      'name': '浦东国际机场',
#      'uid': 'bad9713e7f6bf160f4b916e8',
#      'x': 13560318.96,
#      'y': 3630696.72}]},
#   {'line_name': '地铁7号线(花木路-美兰湖)',
#    'line_uid': 'b872d321ffd171b4e4073840',
#    'pair_line_uid': 'beb059d6f7fadd4ea4da3940',
#    'stops': [{'is_practical': 1,
#      'name': '花木路',
#      'uid': 'f49d6c4f9f3c50008d55ec47',
#      'x': 13533171.73,
#      'y': 3638687.84},
#     {'is_practical': 0,
#      'name': '龙阳路',
#      'uid': '35db393bd64eb41cdaeced47',
#      'x': 13532593.8,
#      'y': 3637699.52},
#     {'is_practical': 1,
#      'name': '芳华路',
#      'uid': '61af70493252e3a58b36ee47',
#      'x': 13531752.5,
#      'y': 3636351.63},
#     {'is_practical': 1,
#      'name': '锦绣路',
#      'uid': '2bdd945565ebb27fcc04ef47',
#      'x': 13530630.38,
#      'y': 3635605.17},
#     {'is_practical': 1,
#      'name': '杨高南路',
#      'uid': 'cec1c3ec3431f54d057ce847',
#      'x': 13528988.81,
#      'y': 3635564.55},
#     {'is_practical': 0,
#      'name': '高科西路',
#      'uid': '9e78923673033c35a31de947',
#      'x': 13527295.18,
#      'y': 3635285.68},
#     {'is_practical': 1,
#      'name': '云台路',
#      'uid': 'cea2d504ba7b9a549c82ea47',
#      'x': 13526267.41,
#      'y': 3634834.19},
#     {'is_practical': 0,
#      'name': '耀华路',
#      'uid': '8a901c7c1c1aa5cb09f5eb47',
#      'x': 13525598.27,
#      'y': 3634352.73},
#     {'is_practical': 1,
#      'name': '长清路',
#      'uid': '42e8ba1d238530bcea12e447',
#      'x': 13524646.56,
#      'y': 3633865.42},
#     {'is_practical': 1,
#      'name': '后滩',
#      'uid': 'ffc37bbbc12e63bf8505bfa5',
#      'x': 13523242.75,
#      'y': 3633548.65},
#     {'is_practical': 0,
#      'name': '龙华中路',
#      'uid': 'eb898582b6f2d35bac31e547',
#      'x': 13521388.62,
#      'y': 3635287.16},
#     {'is_practical': 0,
#      'name': '东安路',
#      'uid': 'd51610f55515957842afe647',
#      'x': 13521116.75,
#      'y': 3636097.11},
#     {'is_practical': 1,
#      'name': '肇嘉浜路',
#      'uid': '4361f31213367be6b917e747',
#      'x': 13520643.82,
#      'y': 3637062.75},
#     {'is_practical': 0,
#      'name': '常熟路',
#      'uid': 'a186b531fda8805e9022e047',
#      'x': 13520514.82,
#      'y': 3639002.18},
#     {'is_practical': 0,
#      'name': '静安寺',
#      'uid': 'e0a55baf0610a96b2802e147',
#      'x': 13520466.33,
#      'y': 3640201.01},
#     {'is_practical': 1,
#      'name': '昌平路',
#      'uid': '0f3ba0172f25114bd52ce247',
#      'x': 13519759.68,
#      'y': 3641655.05},
#     {'is_practical': 1,
#      'name': '长寿路',
#      'uid': 'f78389229705ec65d33ce347',
#      'x': 13519313.64,
#      'y': 3642403.88},
#     {'is_practical': 0,
#      'name': '镇坪路',
#      'uid': 'dfb631026a2bea753717dc47',
#      'x': 13518557.33,
#      'y': 3643324.72},
#     {'is_practical': 1,
#      'name': '岚皋路',
#      'uid': '7896cc2c6c3b0e5e09ccdd47',
#      'x': 13517488,
#      'y': 3644519.5},
#     {'is_practical': 1,
#      'name': '新村路',
#      'uid': '84b8ca3c881030859f95de47',
#      'x': 13517565.19,
#      'y': 3645500.94},
#     {'is_practical': 1,
#      'name': '大华三路',
#      'uid': '81a82e17b6cba6dc4f2fdf47',
#      'x': 13517615.8,
#      'y': 3646800.79},
#     {'is_practical': 1,
#      'name': '行知路',
#      'uid': '648310cc20927666a90dd847',
#      'x': 13517456.82,
#      'y': 3648231.57},
#     {'is_practical': 1,
#      'name': '大场镇',
#      'uid': '5d588695f02890440969d947',
#      'x': 13516887.71,
#      'y': 3649331.55},
#     {'is_practical': 1,
#      'name': '场中路',
#      'uid': 'ca01562f160a30200c3dda47',
#      'x': 13516577.61,
#      'y': 3650660.77},
#     {'is_practical': 1,
#      'name': '上大路',
#      'uid': '19bbb00db66e3574c8c3db47',
#      'x': 13515978,
#      'y': 3652151.16},
#     {'is_practical': 1,
#      'name': '南陈路',
#      'uid': 'fe991069b33af18a08a8d447',
#      'x': 13514914.76,
#      'y': 3652898.82},
#     {'is_practical': 1,
#      'name': '上海大学',
#      'uid': '51fd153d77c431e11911d547',
#      'x': 13513809.59,
#      'y': 3652773.7},
#     {'is_practical': 1,
#      'name': '祁华路',
#      'uid': 'b250cc41144812659d9d68dd',
#      'x': 13512124.62,
#      'y': 3653013.51},
#     {'is_practical': 1,
#      'name': '顾村公园',
#      'uid': '3c0a6be493fd1da9c72ba1e2',
#      'x': 13512030.32,
#      'y': 3655927.53},
#     {'is_practical': 1,
#      'name': '刘行',
#      'uid': '3a36f5042407fd57dc1e52e0',
#      'x': 13510869.9,
#      'y': 3657594.44},
#     {'is_practical': 1,
#      'name': '潘广路',
#      'uid': '2ebeec2619c0964d9a0050e0',
#      'x': 13510135.68,
#      'y': 3658472.74},
#     {'is_practical': 1,
#      'name': '罗南新村',
#      'uid': 'ed0a7efa9be7ff62c17da2e2',
#      'x': 13510346.31,
#      'y': 3661610.83},
#     {'is_practical': 1,
#      'name': '美兰湖',
#      'uid': 'f91476e0792cf934902ca3e2',
#      'x': 13509482.57,
#      'y': 3663359}]},
#   {'line_name': '地铁3号线(江杨北路-上海南站)',
#    'line_uid': '122807887af77d1e8d7727b7',
#    'pair_line_uid': '9d4cd2f0fb50b53e210220b7',
#    'stops': [{'is_practical': 1,
#      'name': '江杨北路',
#      'uid': '9ec6923673033c35a31de9d9',
#      'x': 13519478.11,
#      'y': 3664185.08},
#     {'is_practical': 1,
#      'name': '铁力路',
#      'uid': 'ce1cd504ba7b9a549c82ead9',
#      'x': 13521885.44,
#      'y': 3664196.92},
#     {'is_practical': 1,
#      'name': '友谊路',
#      'uid': '8a2e1c7c1c1aa5cb09f5ebd9',
#      'x': 13523521.6,
#      'y': 3663628.52},
#     {'is_practical': 1,
#      'name': '宝杨路',
#      'uid': '4256ba1d238530bcea12e4d9',
#      'x': 13523920.83,
#      'y': 3662506.86},
#     {'is_practical': 1,
#      'name': '水产路',
#      'uid': 'eb378582b6f2d35bac31e5d9',
#      'x': 13524875.47,
#      'y': 3660664.76},
#     {'is_practical': 1,
#      'name': '淞滨路',
#      'uid': 'd5a810f55515957842afe6d9',
#      'x': 13525397.05,
#      'y': 3659298.61},
#     {'is_practical': 1,
#      'name': '张华浜',
#      'uid': '43dff31213367be6b917e7d9',
#      'x': 13526063.71,
#      'y': 3657622.86},
#     {'is_practical': 1,
#      'name': '淞发路',
#      'uid': 'a138b531fda8805e9022e0d9',
#      'x': 13526260.12,
#      'y': 3655956.96},
#     {'is_practical': 1,
#      'name': '长江南路',
#      'uid': 'e01b5baf0610a96b2802e1d9',
#      'x': 13525263.24,
#      'y': 3654253.33},
#     {'is_practical': 1,
#      'name': '殷高西路',
#      'uid': '0f85a0172f25114bd52ce2d9',
#      'x': 13524516.83,
#      'y': 3652682.39},
#     {'is_practical': 1,
#      'name': '江湾镇',
#      'uid': 'f73d89229705ec65d33ce3d9',
#      'x': 13524534.23,
#      'y': 3650815.06},
#     {'is_practical': 1,
#      'name': '大柏树',
#      'uid': 'df0831026a2bea753717dcd9',
#      'x': 13524309.08,
#      'y': 3648733.34},
#     {'is_practical': 1,
#      'name': '赤峰路',
#      'uid': '7828cc2c6c3b0e5e09ccddd9',
#      'x': 13524239.71,
#      'y': 3647688.84},
#     {'is_practical': 1,
#      'name': '虹口足球场',
#      'uid': '8406ca3c881030859f95ded9',
#      'x': 13523867.93,
#      'y': 3646450.24},
#     {'is_practical': 1,
#      'name': '东宝兴路',
#      'uid': '81162e17b6cba6dc4f2fdfd9',
#      'x': 13523977.9,
#      'y': 3644929.32},
#     {'is_practical': 1,
#      'name': '宝山路',
#      'uid': '643d10cc20927666a90dd8d9',
#      'x': 13523562.84,
#      'y': 3643846.88},
#     {'is_practical': 0,
#      'name': '上海火车站',
#      'uid': '5de68695f02890440969d9d9',
#      'x': 13521541.63,
#      'y': 3643656.83},
#     {'is_practical': 1,
#      'name': '中潭路',
#      'uid': 'cabf562f160a30200c3ddad9',
#      'x': 13519617.29,
#      'y': 3644305.56},
#     {'is_practical': 1,
#      'name': '镇坪路',
#      'uid': '1905b00db66e3574c8c3dbd9',
#      'x': 13518373.19,
#      'y': 3643247.21},
#     {'is_practical': 1,
#      'name': '曹杨路',
#      'uid': 'fe271069b33af18a08a8d4d9',
#      'x': 13517043.76,
#      'y': 3642304.07},
#     {'is_practical': 1,
#      'name': '金沙江路',
#      'uid': '5143153d77c431e11911d5d9',
#      'x': 13516533.08,
#      'y': 3641382.54},
#     {'is_practical': 0,
#      'name': '中山公园',
#      'uid': '5517d1c3b7af2058d02dd6d9',
#      'x': 13516823.27,
#      'y': 3639514.73},
#     {'is_practical': 1,
#      'name': '延安西路',
#      'uid': '92e911a8a616e9644154d7d9',
#      'x': 13516957.88,
#      'y': 3638454.91},
#     {'is_practical': 1,
#      'name': '虹桥路',
#      'uid': '538200116f2a781d240bd0d9',
#      'x': 13517375.87,
#      'y': 3636866.19},
#     {'is_practical': 1,
#      'name': '宜山路',
#      'uid': '453bc92dfe531d422911d1d9',
#      'x': 13518051.22,
#      'y': 3635511.7},
#     {'is_practical': 1,
#      'name': '漕溪路',
#      'uid': '8d0758549b0c105878dbd2d9',
#      'x': 13519313.6,
#      'y': 3634208.22},
#     {'is_practical': 0,
#      'name': '龙漕路',
#      'uid': '1f7e3d0b961641927269d3d9',
#      'x': 13519992.64,
#      'y': 3633269.55},
#     {'is_practical': 1,
#      'name': '石龙路',
#      'uid': '7b213011c7dc4b206da3ccd9',
#      'x': 13519858.02,
#      'y': 3631790.64},
#     {'is_practical': 0,
#      'name': '上海南站',
#      'uid': '493b61dbcd6e54eaaaf0cdd9',
#      'x': 13518467.92,
#      'y': 3631188.3}]},
#   {'line_name': '地铁8号线(沈杜公路-市光路)',
#    'line_uid': '453b2d228cf08f16d4851fb7',
#    'pair_line_uid': '2d6cc6ff85250abeb75f1eb7',
#    'stops': [{'is_practical': 0,
#      'name': '沈杜公路',
#      'uid': '1f6d3d0b961641927269d328',
#      'x': 13527559.4,
#      'y': 3619208.44},
#     {'is_practical': 1,
#      'name': '联航路',
#      'uid': '4528c92dfe531d422911d128',
#      'x': 13527372.25,
#      'y': 3620837.83},
#     {'is_practical': 0,
#      'name': '江月路',
#      'uid': '539100116f2a781d240bd028',
#      'x': 13527149.91,
#      'y': 3622174.35},
#     {'is_practical': 0,
#      'name': '浦江镇',
#      'uid': '5504d1c3b7af2058d02dd628',
#      'x': 13526900.28,
#      'y': 3623753.62},
#     {'is_practical': 1,
#      'name': '芦恒路',
#      'uid': '1916b00db66e3574c8c3db28',
#      'x': 13525952.5,
#      'y': 3626691.83},
#     {'is_practical': 0,
#      'name': '凌兆新村',
#      'uid': 'caac562f160a30200c3dda28',
#      'x': 13525051.04,
#      'y': 3629511.5},
#     {'is_practical': 0,
#      'name': '东方体育中心',
#      'uid': '374b27450b488f6fa6c7560f',
#      'x': 13524019.46,
#      'y': 3631149.5},
#     {'is_practical': 0,
#      'name': '杨思',
#      'uid': '642e10cc20927666a90dd828',
#      'x': 13525497.6,
#      'y': 3632102.03},
#     {'is_practical': 0,
#      'name': '成山路',
#      'uid': '8415ca3c881030859f95de28',
#      'x': 13525769.23,
#      'y': 3633366.7},
#     {'is_practical': 0,
#      'name': '耀华路',
#      'uid': '60ca431028f771b516948ede',
#      'x': 13525589.33,
#      'y': 3634358.85},
#     {'is_practical': 0,
#      'name': '中华艺术宫',
#      'uid': 'f350bbc3b7af2058d02dd61d',
#      'x': 13525496.84,
#      'y': 3635238.43},
#     {'is_practical': 0,
#      'name': '西藏南路',
#      'uid': '783b8ef0f7fb2fddbbdf8fde',
#      'x': 13525030.64,
#      'y': 3637412.98},
#     {'is_practical': 0,
#      'name': '陆家浜路',
#      'uid': 'b4db51fca993829689b988de',
#      'x': 13524656.1,
#      'y': 3638661.99},
#     {'is_practical': 0,
#      'name': '老西门',
#      'uid': '6cd70f9404d8b0f08d1a89de',
#      'x': 13524294.74,
#      'y': 3639608.04},
#     {'is_practical': 0,
#      'name': '大世界',
#      'uid': '33bfa2df36beb45380288ade',
#      'x': 13523894.02,
#      'y': 3640703.1},
#     {'is_practical': 0,
#      'name': '人民广场',
#      'uid': '9df490b9321db961dcee8bde',
#      'x': 13523472.35,
#      'y': 3641424.11},
#     {'is_practical': 0,
#      'name': '曲阜路',
#      'uid': 'ae92941a3f2fe5a796ec84de',
#      'x': 13523018.05,
#      'y': 3642664.79},
#     {'is_practical': 0,
#      'name': '中兴路',
#      'uid': 'a531992863e9afa5fadc85de',
#      'x': 13522728.07,
#      'y': 3644059.74},
#     {'is_practical': 0,
#      'name': '西藏北路',
#      'uid': 'a903c5ee29ebc3955ebe86de',
#      'x': 13522710.11,
#      'y': 3645402.83},
#     {'is_practical': 0,
#      'name': '虹口足球场',
#      'uid': 'f6c58fec45db67f7714b87de',
#      'x': 13523902.68,
#      'y': 3646229.9},
#     {'is_practical': 0,
#      'name': '曲阳路',
#      'uid': 'bdc7e3dce1b94802705e80de',
#      'x': 13525135.68,
#      'y': 3647051.65},
#     {'is_practical': 0,
#      'name': '四平路',
#      'uid': 'd6f747bece4c4917b03c81de',
#      'x': 13526336.3,
#      'y': 3646850.37},
#     {'is_practical': 0,
#      'name': '鞍山新村',
#      'uid': '7395684bcf598975e9e582de',
#      'x': 13527253.79,
#      'y': 3646636.95},
#     {'is_practical': 0,
#      'name': '江浦路',
#      'uid': '5f60695e0f3bd0acf12d83de',
#      'x': 13528226.46,
#      'y': 3646882.62},
#     {'is_practical': 0,
#      'name': '黄兴路',
#      'uid': '5f75a93c56e2c864f5eafcde',
#      'x': 13529299.28,
#      'y': 3647369.34},
#     {'is_practical': 0,
#      'name': '延吉中路',
#      'uid': '8017f0e54e2acca33813fdde',
#      'x': 13530074.5,
#      'y': 3648685.19},
#     {'is_practical': 0,
#      'name': '黄兴公园',
#      'uid': 'd8cee82d4aed015a5ed4fede',
#      'x': 13529882.18,
#      'y': 3649619.8},
#     {'is_practical': 0,
#      'name': '翔殷路',
#      'uid': 'c306ecea8714679d55bfffde',
#      'x': 13529748,
#      'y': 3650798.3},
#     {'is_practical': 0,
#      'name': '嫩江路',
#      'uid': 'c6c12113e1d36cf6ef74f8de',
#      'x': 13529757.66,
#      'y': 3652081.81},
#     {'is_practical': 0,
#      'name': '市光路',
#      'uid': '0c3847d4eab8d63de315f9de',
#      'x': 13529754.13,
#      'y': 3653066.38}]},
#   {'line_name': '地铁6号线(港城路-东方体育中心)',
#    'line_uid': '1cb3370223e487e1d0ff23b7',
#    'pair_line_uid': '0e27a9a86ef8036b32f71db7',
#    'stops': [{'is_practical': 1,
#      'name': '港城路',
#      'uid': 'b3721bece30ad8582ab97cd9',
#      'x': 13534498.75,
#      'y': 3657058.65},
#     {'is_practical': 1,
#      'name': '外高桥保税区北',
#      'uid': 'b2c6450d5e1613f0b3077dd9',
#      'x': 13535867.64,
#      'y': 3656356.34},
#     {'is_practical': 1,
#      'name': '航津路',
#      'uid': 'ed27f81195be8a4e2db17ed9',
#      'x': 13536657.33,
#      'y': 3654724.89},
#     {'is_practical': 1,
#      'name': '外高桥保税区南',
#      'uid': '533b33b90c0014f8b7147fd9',
#      'x': 13537548.09,
#      'y': 3652929.43},
#     {'is_practical': 1,
#      'name': '洲海路',
#      'uid': '9993aa0792b68e5dffa778d9',
#      'x': 13536143.36,
#      'y': 3651748.78},
#     {'is_practical': 1,
#      'name': '五洲大道',
#      'uid': '072d34b10813c6ee9ef779d9',
#      'x': 13536134.99,
#      'y': 3650487.27},
#     {'is_practical': 1,
#      'name': '东靖路',
#      'uid': '989bae1440a0a7beadee7ad9',
#      'x': 13536077.2,
#      'y': 3648954.75},
#     {'is_practical': 0,
#      'name': '巨峰路',
#      'uid': '013ee6a721f094a72de67bd9',
#      'x': 13536039.49,
#      'y': 3647617.88},
#     {'is_practical': 1,
#      'name': '五莲路',
#      'uid': '488d87f712e914af44e274d9',
#      'x': 13535989.59,
#      'y': 3646518.34},
#     {'is_practical': 1,
#      'name': '博兴路',
#      'uid': '26ddb4ee92e17dabc71b75d9',
#      'x': 13535864.16,
#      'y': 3645488.11},
#     {'is_practical': 1,
#      'name': '金桥路',
#      'uid': '14c434e6fbe5fe527fc876d9',
#      'x': 13535303.1,
#      'y': 3644611.31},
#     {'is_practical': 1,
#      'name': '云山路',
#      'uid': '97cc5de2781c4681f70e77d9',
#      'x': 13534294.56,
#      'y': 3643751.83},
#     {'is_practical': 1,
#      'name': '德平路',
#      'uid': 'ffc8de1bc0cfce470e0a70d9',
#      'x': 13533321.57,
#      'y': 3643104},
#     {'is_practical': 1,
#      'name': '北洋泾路',
#      'uid': '7b3166c848093743353a71d9',
#      'x': 13532058.71,
#      'y': 3642317.37},
#     {'is_practical': 1,
#      'name': '民生路',
#      'uid': 'c2e2ee0eb10d0c73038972d9',
#      'x': 13531023.04,
#      'y': 3641867.41},
#     {'is_practical': 1,
#      'name': '源深体育中心',
#      'uid': '4924170a8a3d3ac08adb73d9',
#      'x': 13530017.43,
#      'y': 3641469.51},
#     {'is_practical': 0,
#      'name': '世纪大道',
#      'uid': 'b1202c3abc8eb39234b06cd9',
#      'x': 13529230.55,
#      'y': 3640903.64},
#     {'is_practical': 1,
#      'name': '浦电路',
#      'uid': 'f5101a8935dc0df92eb96dd9',
#      'x': 13529412.37,
#      'y': 3639786.19},
#     {'is_practical': 0,
#      'name': '蓝村路',
#      'uid': 'c2a393db8bb717f04c776ed9',
#      'x': 13529279.36,
#      'y': 3638697.13},
#     {'is_practical': 1,
#      'name': '上海儿童医学中心',
#      'uid': '48f12db091be753e06026fd9',
#      'x': 13528781.54,
#      'y': 3637629.61},
#     {'is_practical': 1,
#      'name': '临沂新村',
#      'uid': 'f79a37b9f3703f4b9f9d68d9',
#      'x': 13528034.58,
#      'y': 3636276.19},
#     {'is_practical': 1,
#      'name': '高科西路',
#      'uid': 'ea935577b905a6d4760269d9',
#      'x': 13527290.5,
#      'y': 3635277.83},
#     {'is_practical': 1,
#      'name': '东明路',
#      'uid': '895d1f02209a4f4bb15c6ad9',
#      'x': 13527412.04,
#      'y': 3633596.06},
#     {'is_practical': 1,
#      'name': '高青路',
#      'uid': 'c028869dc90588150d0e6bd9',
#      'x': 13527944.37,
#      'y': 3631912.74},
#     {'is_practical': 1,
#      'name': '华夏西路',
#      'uid': '58b76f020e5b3447a00464d9',
#      'x': 13527819.21,
#      'y': 3630660.11},
#     {'is_practical': 1,
#      'name': '上南路',
#      'uid': 'be28a85cb209994de7e965d9',
#      'x': 13526907.61,
#      'y': 3630558.87},
#     {'is_practical': 1,
#      'name': '灵岩南路',
#      'uid': '7876140e1f03dea0accb66d9',
#      'x': 13525652.33,
#      'y': 3630504.34},
#     {'is_practical': 0,
#      'name': '东方体育中心',
#      'uid': 'fc341a3a16104a0cb44f540f',
#      'x': 13524019.46,
#      'y': 3631149.5}]},
#   {'line_name': '地铁9号线(松江南站-曹路)',
#    'line_uid': 'afe624f70958ecccdb1318b7',
#    'pair_line_uid': 'a533a15f6a82e35a970319b7',
#    'stops': [{'is_practical': 0,
#      'name': '松江南站',
#      'uid': 'c2e8721213367be6b917e7cd',
#      'x': 13496229.41,
#      'y': 3609376.99},
#     {'is_practical': 0,
#      'name': '醉白池',
#      'uid': '260f3431fda8805e9022e0cd',
#      'x': 13496057.65,
#      'y': 3611443.15},
#     {'is_practical': 0,
#      'name': '松江体育中心',
#      'uid': '612cdaaf0610a96b2802e1cd',
#      'x': 13496197.88,
#      'y': 3613389.69},
#     {'is_practical': 1,
#      'name': '松江新城',
#      'uid': '6bff4cbf5073da5cea56fade',
#      'x': 13496216.79,
#      'y': 3615220.17},
#     {'is_practical': 1,
#      'name': '松江大学城',
#      'uid': '6394f6745c12d31fc7effbde',
#      'x': 13496433,
#      'y': 3618301.29},
#     {'is_practical': 1,
#      'name': '洞泾',
#      'uid': 'd85ffa155551fea63786f4de',
#      'x': 13496189.54,
#      'y': 3622226.66},
#     {'is_practical': 1,
#      'name': '佘山',
#      'uid': 'db3ef35678e80ecf05fef5de',
#      'x': 13496105.22,
#      'y': 3624841.86},
#     {'is_practical': 1,
#      'name': '泗泾',
#      'uid': 'd37ddeef88813cb716c8f6de',
#      'x': 13499556.36,
#      'y': 3626571.26},
#     {'is_practical': 1,
#      'name': '九亭',
#      'uid': '104274a315f7134fc3f1cfde',
#      'x': 13506026.3,
#      'y': 3629142.38},
#     {'is_practical': 1,
#      'name': '中春路',
#      'uid': '0e88b3f09501fab8583ac8de',
#      'x': 13508181.96,
#      'y': 3630709.73},
#     {'is_practical': 1,
#      'name': '七宝',
#      'uid': 'cedb33067cf66173911fc9de',
#      'x': 13509440.57,
#      'y': 3631413.78},
#     {'is_practical': 1,
#      'name': '星中路',
#      'uid': '4f2ddaf1e73da856efdfcade',
#      'x': 13511613.74,
#      'y': 3631733.46},
#     {'is_practical': 1,
#      'name': '合川路',
#      'uid': 'a5da413a2e18d696f9f0cbde',
#      'x': 13513350.13,
#      'y': 3632816.08},
#     {'is_practical': 1,
#      'name': '漕河泾开发区',
#      'uid': '3f11881f50d8c0b9a1acc4de',
#      'x': 13514796.77,
#      'y': 3633333.22},
#     {'is_practical': 1,
#      'name': '桂林路',
#      'uid': 'f934f6df46f798e550e5c5de',
#      'x': 13517114.22,
#      'y': 3633952.26},
#     {'is_practical': 0,
#      'name': '宜山路',
#      'uid': '86f4e0f01eab69ac1a94c6de',
#      'x': 13518128.85,
#      'y': 3635270.56},
#     {'is_practical': 0,
#      'name': '徐家汇',
#      'uid': '6ebdaa1e4c1e9a9b3de23147',
#      'x': 13519155.58,
#      'y': 3636662.84},
#     {'is_practical': 0,
#      'name': '肇嘉浜路',
#      'uid': 'ce8aea191cd504ab461a3247',
#      'x': 13520593.61,
#      'y': 3637158.59},
#     {'is_practical': 0,
#      'name': '嘉善路',
#      'uid': '8d8dbad282e57f532f473347',
#      'x': 13521816.11,
#      'y': 3637570.62},
#     {'is_practical': 0,
#      'name': '打浦桥',
#      'uid': 'dc4624e2f91d160e6dc02c47',
#      'x': 13522726.98,
#      'y': 3637975.92},
#     {'is_practical': 0,
#      'name': '马当路',
#      'uid': 'bd765f1a9040548902ff2d47',
#      'x': 13523650.56,
#      'y': 3638380.04},
#     {'is_practical': 0,
#      'name': '陆家浜路',
#      'uid': 'c78e3647d2c73bb683a12e47',
#      'x': 13524647.2,
#      'y': 3638666.42},
#     {'is_practical': 0,
#      'name': '小南门',
#      'uid': 'add374c0bdf8bae8b7f42f47',
#      'x': 13526010.17,
#      'y': 3639346.55},
#     {'is_practical': 0,
#      'name': '商城路',
#      'uid': 'ee541bff3ca68ebddb2f2847',
#      'x': 13528013.38,
#      'y': 3641091.43},
#     {'is_practical': 0,
#      'name': '世纪大道',
#      'uid': '866b9aa108f3e266aaf72947',
#      'x': 13529184.46,
#      'y': 3640921.24},
#     {'is_practical': 1,
#      'name': '杨高中路',
#      'uid': '001e2c58bdeb6544e0110387',
#      'x': 13531590.35,
#      'y': 3640789.03},
#     {'is_practical': 1,
#      'name': '芳甸路',
#      'uid': 'f43a7ca2a9847dce94ec84ab',
#      'x': 13532658.84,
#      'y': 3641295.91},
#     {'is_practical': 0,
#      'name': '蓝天路',
#      'uid': '1d306852d233a56d250bd091',
#      'x': 13534834.94,
#      'y': 3642567.77},
#     {'is_practical': 1,
#      'name': '台儿庄路',
#      'uid': 'e505d8ac3ca2642148cc4aa1',
#      'x': 13537040.85,
#      'y': 3644016.95},
#     {'is_practical': 0,
#      'name': '金桥',
#      'uid': '41f8f7eec4436e757adbd29f',
#      'x': 13538719.61,
#      'y': 3645077.39},
#     {'is_practical': 0,
#      'name': '金吉路',
#      'uid': '5cbc048553fbbee5d03ce3b4',
#      'x': 13540426.87,
#      'y': 3645472.84},
#     {'is_practical': 0,
#      'name': '金海路',
#      'uid': '4167d2a25b2970f31e1d11b1',
#      'x': 13541658.11,
#      'y': 3645414.67},
#     {'is_practical': 1,
#      'name': '顾唐路',
#      'uid': 'e4e7450ac996e3c732870a15',
#      'x': 13543610.62,
#      'y': 3645764.14},
#     {'is_practical': 0,
#      'name': '民雷路',
#      'uid': '86ffc4015e4e64659b68b4ea',
#      'x': 13544902.94,
#      'y': 3646083.17},
#     {'is_practical': 0,
#      'name': '曹路',
#      'uid': '2a41567098c7e47517948e63',
#      'x': 13546554.93,
#      'y': 3646459.03}]},
#   {'line_name': '地铁6号线(东方体育中心-港城路)',
#    'line_uid': '0e27a9a86ef8036b32f71db7',
#    'pair_line_uid': '1cb3370223e487e1d0ff23b7',
#    'stops': [{'is_practical': 0,
#      'name': '东方体育中心',
#      'uid': 'd366fd17cc428d06b626550f',
#      'x': 13524019.46,
#      'y': 3631149.5},
#     {'is_practical': 0,
#      'name': '灵岩南路',
#      'uid': 'c724b90458ee9582611c67d9',
#      'x': 13525652.33,
#      'y': 3630504.34},
#     {'is_practical': 0,
#      'name': '上南路',
#      'uid': '6b2efee913cc58556d4760d9',
#      'x': 13526907.61,
#      'y': 3630558.87},
#     {'is_practical': 0,
#      'name': '华夏西路',
#      'uid': '2bc3b5cbde1b540ef92d61d9',
#      'x': 13527819.21,
#      'y': 3630660.11},
#     {'is_practical': 0,
#      'name': '高青路',
#      'uid': '61e1781cd240c064200262d9',
#      'x': 13527944.37,
#      'y': 3631912.74},
#     {'is_practical': 0,
#      'name': '东明路',
#      'uid': 'af367447462a194bb9bd63d9',
#      'x': 13527412.04,
#      'y': 3633596.06},
#     {'is_practical': 0,
#      'name': '高科西路',
#      'uid': 'a26de02d9f0580f47bb55cd9',
#      'x': 13527290.5,
#      'y': 3635277.83},
#     {'is_practical': 0,
#      'name': '临沂新村',
#      'uid': '2907390206ba42fc8af15dd9',
#      'x': 13528034.58,
#      'y': 3636276.19},
#     {'is_practical': 0,
#      'name': '上海儿童医学中心',
#      'uid': 'f128a0bdc4b2b3b83e9a5ed9',
#      'x': 13528781.54,
#      'y': 3637629.61},
# ...
#     {'is_practical': 1,
#      'name': '共康路',
#      'uid': '753ca548a87161f27e29bdd9',
#      'x': 13520284.91,
#      'y': 3652656.48},
#     {'is_practical': 1,
#      'name': '彭浦新村',
#      'uid': '4d610e76e7bc47605af6bed9',
#      'x': 13520466.61,
#      'y': 3651047.06},
#     {'is_practical': 1,
#      'name': '汶水路',
#      'uid': 'e55f41bbc12e63bf8405bfd9',
#      'x': 13520629.55,
#      'y': 3649215.52},
#     {'is_practical': 1,
#      'name': '上海马戏城',
#      'uid': 'ab926729e5f1bd4cf703b8d9',
#      'x': 13520845.8,
#      'y': 3647534.26},
#     {'is_practical': 1,
#      'name': '延长路',
#      'uid': '8a0043f63b02ce4a6c20b9d9',
#      'x': 13521223.19,
#      'y': 3646525.17},
#     {'is_practical': 1,
#      'name': '中山北路',
#      'uid': 'afdf9d0548045569f23cbad9',
#      'x': 13521637.61,
#      'y': 3644868.24},
#     {'is_practical': 1,
#      'name': '上海火车站',
#      'uid': '722cee03d327cb7527d2bbd9',
#      'x': 13521276.61,
#      'y': 3643356.86},
#     {'is_practical': 0,
#      'name': '汉中路',
#      'uid': '002a75204d3b1e9b9968b4d9',
#      'x': 13521570.09,
#      'y': 3642617.7},
#     {'is_practical': 1,
#      'name': '新闸路',
#      'uid': '9409eb3c98d5a0218a2fb5d9',
#      'x': 13522660.22,
#      'y': 3642202.16},
#     {'is_practical': 1,
#      'name': '人民广场',
#      'uid': '0b153ed2266fb36677e5b6d9',
#      'x': 13523427.94,
#      'y': 3641450.87},
#     {'is_practical': 1,
#      'name': '黄陂南路',
#      'uid': 'ddfb806835284eacd718b7d9',
#      'x': 13523216.39,
#      'y': 3640136.36},
#     {'is_practical': 1,
#      'name': '陕西南路',
#      'uid': '6241932fc8e2ee51ff0eb0d9',
#      'x': 13521755.27,
#      'y': 3639455.27},
#     {'is_practical': 1,
#      'name': '常熟路',
#      'uid': '76066ee5681fc6473804b1d9',
#      'x': 13520759.48,
#      'y': 3638993.65},
#     {'is_practical': 1,
#      'name': '衡山路',
#      'uid': '8accce184009014dfb42b2d9',
#      'x': 13520251.08,
#      'y': 3637880.34},
#     {'is_practical': 0,
#      'name': '徐家汇',
#      'uid': '2931e60e8703c20b0b5cb3d9',
#      'x': 13519314.04,
#      'y': 3636301.58},
#     {'is_practical': 1,
#      'name': '上海体育馆',
#      'uid': '0027210444453215c256acd9',
#      'x': 13519101.32,
#      'y': 3634904.04},
#     {'is_practical': 1,
#      'name': '漕宝路',
#      'uid': '382ee242b45bfb1ff80cadd9',
#      'x': 13518971.87,
#      'y': 3633108},
#     {'is_practical': 1,
#      'name': '上海南站',
#      'uid': 'fa68125c7d51c145374aaed9',
#      'x': 13518368.54,
#      'y': 3631388.35},
#     {'is_practical': 1,
#      'name': '锦江乐园',
#      'uid': '0976db56470b0e033210afd9',
#      'x': 13516635.39,
#      'y': 3629720.63},
#     {'is_practical': 1,
#      'name': '莲花路',
#      'uid': 'c17ce10c884d0b59b120a8d9',
#      'x': 13515372.3,
#      'y': 3628222.27},
#     {'is_practical': 1,
#      'name': '外环路',
#      'uid': 'fc262e4a8d1788696040a9d9',
#      'x': 13514290.78,
#      'y': 3626917.96},
#     {'is_practical': 0,
#      'name': '莘庄',
#      'uid': '32602b100e275909110daad9',
#      'x': 13513400.74,
#      'y': 3625614.49}]},
#   {'line_name': '地铁3号线(上海南站-江杨北路)',
#    'line_uid': '9d4cd2f0fb50b53e210220b7',
#    'pair_line_uid': '122807887af77d1e8d7727b7',
#    'stops': [{'is_practical': 0,
#      'name': '上海南站',
#      'uid': '19f16b69d2a493b92a06ced9',
#      'x': 13518467.92,
#      'y': 3631188.3},
#     {'is_practical': 0,
#      'name': '石龙路',
#      'uid': '104374a315f7134fc3f1cfd9',
#      'x': 13519858.02,
#      'y': 3631790.64},
#     {'is_practical': 0,
#      'name': '龙漕路',
#      'uid': '0e89b3f09501fab8583ac8d9',
#      'x': 13519992.64,
#      'y': 3633269.55},
#     {'is_practical': 0,
#      'name': '漕溪路',
#      'uid': 'ceda33067cf66173911fc9d9',
#      'x': 13519313.6,
#      'y': 3634208.22},
#     {'is_practical': 0,
#      'name': '宜山路',
#      'uid': '4f2cdaf1e73da856efdfcad9',
#      'x': 13518051.22,
#      'y': 3635511.7},
#     {'is_practical': 0,
#      'name': '虹桥路',
#      'uid': 'a5db413a2e18d696f9f0cbd9',
#      'x': 13517375.87,
#      'y': 3636866.19},
#     {'is_practical': 0,
#      'name': '延安西路',
#      'uid': '3f10881f50d8c0b9a1acc4d9',
#      'x': 13516957.88,
#      'y': 3638454.91},
#     {'is_practical': 0,
#      'name': '中山公园',
#      'uid': 'f935f6df46f798e550e5c5d9',
#      'x': 13516823.27,
#      'y': 3639514.73},
#     {'is_practical': 0,
#      'name': '金沙江路',
#      'uid': '86f5e0f01eab69ac1a94c6d9',
#      'x': 13516533.08,
#      'y': 3641382.54},
#     {'is_practical': 0,
#      'name': '曹杨路',
#      'uid': '93dab8acefe223dd0a1cc7d9',
#      'x': 13517043.76,
#      'y': 3642304.07},
#     {'is_practical': 0,
#      'name': '镇坪路',
#      'uid': 'ca8649e5a59333554351c0d9',
#      'x': 13518373.19,
#      'y': 3643247.21},
#     {'is_practical': 0,
#      'name': '中潭路',
#      'uid': '3ccf0394b51b7a184007c1d9',
#      'x': 13519617.29,
#      'y': 3644305.56},
#     {'is_practical': 0,
#      'name': '上海火车站',
#      'uid': '77be131cfc56794e0582c2d9',
#      'x': 13521541.63,
#      'y': 3643656.83},
#     {'is_practical': 0,
#      'name': '宝山路',
#      'uid': '64365a51ff003ccb5c17c3d9',
#      'x': 13523562.84,
#      'y': 3643846.88},
#     {'is_practical': 0,
#      'name': '东宝兴路',
#      'uid': '2c7b5907ba85655ecbe33cd9',
#      'x': 13523977.9,
#      'y': 3644929.32},
#     {'is_practical': 0,
#      'name': '虹口足球场',
#      'uid': '302d1c82e310f2aaca213dd9',
#      'x': 13523867.93,
#      'y': 3646450.24},
#     {'is_practical': 0,
#      'name': '赤峰路',
#      'uid': '74a8451774e4f36840d63ed9',
#      'x': 13524239.71,
#      'y': 3647688.84},
#     {'is_practical': 0,
#      'name': '大柏树',
#      'uid': '2e3dd2e37526799f48fd3fd9',
#      'x': 13524309.08,
#      'y': 3648733.34},
#     {'is_practical': 0,
#      'name': '江湾镇',
#      'uid': 'b8c9d321ffd171b4e40738d9',
#      'x': 13524534.23,
#      'y': 3650815.06},
#     {'is_practical': 0,
#      'name': '殷高西路',
#      'uid': 'be0b59d6f7fadd4ea4da39d9',
#      'x': 13524516.83,
#      'y': 3652682.39},
#     {'is_practical': 0,
#      'name': '长江南路',
#      'uid': '35fc51fd5b009d930bb93ad9',
#      'x': 13525263.24,
#      'y': 3654253.33},
#     {'is_practical': 0,
#      'name': '淞发路',
#      'uid': '3ed7fd071bdd32f0f6e73bd9',
#      'x': 13526260.12,
#      'y': 3655956.96},
#     {'is_practical': 0,
#      'name': '张华浜',
#      'uid': '932dbddab4becfaea3a934d9',
#      'x': 13526063.71,
#      'y': 3657622.86},
#     {'is_practical': 0,
#      'name': '淞滨路',
#      'uid': 'dcf012b949e09ae0122935d9',
#      'x': 13525397.05,
#      'y': 3659298.61},
#     {'is_practical': 0,
#      'name': '水产路',
#      'uid': '7293efe71cae2b60b31e36d9',
#      'x': 13524875.47,
#      'y': 3660664.76},
#     {'is_practical': 0,
#      'name': '宝杨路',
#      'uid': '8ccdbaa9ad2e8a57f31937d9',
#      'x': 13523920.83,
#      'y': 3662506.86},
#     {'is_practical': 0,
#      'name': '友谊路',
#      'uid': 'd8830b290c19ca50a3d230d9',
#      'x': 13523521.6,
#      'y': 3663628.52},
#     {'is_practical': 0,
#      'name': '铁力路',
#      'uid': '6e03aa1e4c1e9a9b3de231d9',
#      'x': 13521885.44,
#      'y': 3664196.92},
#     {'is_practical': 0,
#      'name': '江杨北路',
#      'uid': 'ce34ea191cd504ab461a32d9',
#      'x': 13519478.11,
#      'y': 3664185.08}]},
#   {'line_name': '地铁13号线(张江路-金运路)',
#    'line_uid': '8cb221172f25114bd52ce2cd',
#    'pair_line_uid': 'e226f1493252e3a58b36eecd',
#    'stops': [{'is_practical': 0,
#      'name': '张江路',
#      'uid': 'd49e59375c12abef1b11d5b9',
#      'x': 13540551.54,
#      'y': 3635757.76},
#     {'is_practical': 0,
#      'name': '学林路',
#      'uid': '434f75cad8e6f740f90cad07',
#      'x': 13538916.91,
#      'y': 3635001.86},
#     {'is_practical': 0,
#      'name': '中科路',
#      'uid': '58e0671ec20a607c39221ca4',
#      'x': 13537603.87,
#      'y': 3634424.99},
#     {'is_practical': 0,
#      'name': '华夏中路',
#      'uid': '1f882104be169922f90cad30',
#      'x': 13535281.86,
#      'y': 3633897.67},
#     {'is_practical': 1,
#      'name': '莲溪路',
#      'uid': '7d3d4b671a7c591995ca07a9',
#      'x': 13533541.95,
#      'y': 3633219.81},
#     {'is_practical': 1,
#      'name': '陈春路',
#      'uid': '085aa80dc4627b3972455b2f',
#      'x': 13532593.88,
#      'y': 3633996},
#     {'is_practical': 1,
#      'name': '北蔡',
#      'uid': '34a74e64468c7b392b201a16',
#      'x': 13532006.86,
#      'y': 3634660.01},
#     {'is_practical': 0,
#      'name': '下南路',
#      'uid': '147cb0273d1b24f48f1a89e4',
#      'x': 13530660.88,
#      'y': 3634538.98},
#     {'is_practical': 1,
#      'name': '华鹏路',
#      'uid': 'e8717567be90f3bd260bd055',
#      'x': 13529192.92,
#      'y': 3634138.79},
#     {'is_practical': 0,
#      'name': '东明路',
#      'uid': '1ecf85f32a3ae0090bf5ebac',
#      'x': 13527581.96,
#      'y': 3633637.66},
#     {'is_practical': 1,
#      'name': '成山路',
#      'uid': 'bda7c3c36c0e2bd52fb908c5',
#      'x': 13525886.89,
#      'y': 3633452.78},
#     {'is_practical': 1,
#      'name': '长清路',
#      'uid': '8e96868f139f405cc17da27d',
#      'x': 13524943.08,
#      'y': 3633764.94},
#     {'is_practical': 0,
#      'name': '世博大道',
#      'uid': '7b88e57f9a6e87a6e812e434',
#      'x': 13524456.36,
#      'y': 3634888.3},
#     {'is_practical': 0,
#      'name': '世博会博物馆',
#      'uid': '6c8160ae1227a9112102209c',
#      'x': 13524186.73,
#      'y': 3636749.87},
#     {'is_practical': 0,
#      'name': '马当路',
#      'uid': 'df46614cad47ed9a374aae1e',
#      'x': 13523564.24,
#      'y': 3638422.29},
#     {'is_practical': 0,
#      'name': '新天地',
#      'uid': '437efcea484bb9e49f09f742',
#      'x': 13523398.29,
#      'y': 3639197.4},
#     {'is_practical': 0,
#      'name': '淮海中路',
#      'uid': '14eb9e508c60f5c62b201a60',
#      'x': 13522201.03,
#      'y': 3639805.36},
#     {'is_practical': 0,
#      'name': '南京西路',
#      'uid': '525951b36357f723c51b75dd',
#      'x': 13522008.71,
#      'y': 3640899.7},
#     {'is_practical': 1,
#      'name': '自然博物馆',
#      'uid': 'b2f6b6a0f1d2b6c586420e1b',
#      'x': 13522045.42,
#      'y': 3641841.72},
#     {'is_practical': 0,
#      'name': '汉中路',
#      'uid': '82a6787ab89ec440f7eafc8a',
#      'x': 13521615.25,
#      'y': 3642475.04},
#     {'is_practical': 1,
#      'name': '江宁路',
#      'uid': 'c877b379def72b6f4207c108',
#      'x': 13519962.58,
#      'y': 3642960.55},
#     {'is_practical': 0,
#      'name': '长寿路',
#      'uid': 'a934ab6dfbf9bd992a02e1d3',
#      'x': 13519318.81,
#      'y': 3642523.51},
#     {'is_practical': 1,
#      'name': '武宁路',
#      'uid': '0492d312a0a8ae1d8bfc061a',
#      'x': 13518415.95,
#      'y': 3641631.11},
#     {'is_practical': 0,
#      'name': '隆德路',
#      'uid': 'b2a3417ebe18c41530169bf8',
#      'x': 13517644.29,
#      'y': 3641166.03},
#     {'is_practical': 0,
#      'name': '金沙江路',
#      'uid': '760a08229705ec65d33ce3cd',
#      'x': 13516448.08,
#      'y': 3641234.13},
#     {'is_practical': 1,
#      'name': '大渡河路',
#      'uid': '253b63fbfb3c710049fd3f9a',
#      'x': 13514523.26,
#      'y': 3641274.02},
#     {'is_practical': 0,
#      'name': '真北路',
#      'uid': '403fb0026a2bea753717dccd',
#      'x': 13513096.13,
#      'y': 3641316.29},
#     {'is_practical': 0,
#      'name': '祁连山南路',
#      'uid': 'ccbc1d15034f2e3f58bbbcd2',
#      'x': 13511454.76,
#      'y': 3642004.08},
#     {'is_practical': 0,
#      'name': '丰庄',
#      'uid': 'f91f4d2c6c3b0e5e09ccddcd',
#      'x': 13510123.37,
#      'y': 3642677.52},
#     {'is_practical': 0,
#      'name': '金沙江西路',
#      'uid': '07314b3c881030859f95decd',
#      'x': 13507842.2,
#      'y': 3642552.01},
#     {'is_practical': 0,
#      'name': '金运路',
#      'uid': '0021af17b6cba6dc4f2fdfcd',
#      'x': 13506099.44,
#      'y': 3642547.96}]},
#   {'line_name': '磁悬浮(磁浮机场-龙阳路)',
#    'line_uid': 'fbdbf8df46f798e551e5c5b7',
#    'pair_line_uid': '219bc2856514af4a28201ab7',
#    'stops': [{'is_practical': 0,
#      'name': '磁浮机场',
#      'uid': '7292efe71cae2b60b31e36de',
#      'x': 13560220.9,
#      'y': 3630864.82},
#     {'is_practical': 0,
#      'name': '龙阳路',
#      'uid': '8cccbaa9ad2e8a57f31937de',
#      'x': 13532619.85,
#      'y': 3637571.9}]},
#   {'line_name': '地铁17号线(东方绿舟-虹桥火车站)',
#    'line_uid': 'a4d2e449410a5ef31ce999c0',
#    'pair_line_uid': 'e8608705a4116f6abda240bb',
#    'stops': [{'is_practical': 1,
#      'name': '东方绿舟',
#      'uid': 'dd6fd21c7601fbb5deee8bad',
#      'x': 13472730.81,
#      'y': 3624008.81},
#     {'is_practical': 0,
#      'name': '朱家角',
#      'uid': '5e694fbd7b0d2921adcb6619',
#      'x': 13476118.31,
#      'y': 3624376.58},
#     {'is_practical': 0,
#      'name': '淀山湖大道',
#      'uid': '4b19d33fbe87c1a540e19211',
#      'x': 13479660.94,
#      'y': 3628741.88},
#     {'is_practical': 0,
#      'name': '漕盈路',
#      'uid': '666e997bf92f9d64dbd8915b',
#      'x': 13481238.75,
#      'y': 3632094.12},
#     {'is_practical': 0,
#      'name': '青浦新城',
#      'uid': 'f3643e7084c678cbc9fa5f84',
#      'x': 13484465.59,
#      'y': 3631818.32},
#     {'is_practical': 1,
#      'name': '汇金路',
#      'uid': '2fe9c97bd55686164bcc4a14',
#      'x': 13487430.89,
#      'y': 3632131.84},
#     {'is_practical': 1,
#      'name': '赵巷',
#      'uid': '1b5d94ae4b312ca470210b1b',
#      'x': 13491926.87,
#      'y': 3632197.89},
#     {'is_practical': 1,
#      'name': '嘉松中路',
#      'uid': '5465d4dec5c7ef2316a19032',
#      'x': 13495554.26,
#      'y': 3632529.51},
#     {'is_practical': 0,
#      'name': '徐泾北城',
#      'uid': 'bffb5f8813e28ae6c056ac7f',
#      'x': 13497453.88,
#      'y': 3633986.91},
#     {'is_practical': 1,
#      'name': '徐盈路',
#      'uid': '1a43831955560e80b45f1e1f',
#      'x': 13498883.73,
#      'y': 3634351.75},
#     {'is_practical': 0,
#      'name': '蟠龙路',
#      'uid': '88f2ea99179ad9a0abf729e1',
#      'x': 13501643.81,
#      'y': 3635486.11},
#     {'is_practical': 0,
#      'name': '诸光路',
#      'uid': '5f5a48f9818ec026d518b7dd',
#      'x': 13503161.15,
#      'y': 3636137.25},
#     {'is_practical': 0,
#      'name': '虹桥火车站',
#      'uid': '6561c096b2fb91bff4eafc38',
#      'x': 13506307.63,
#      'y': 3636462.03}]},
#   {'line_name': '地铁17号线(虹桥火车站-东方绿舟)',
#    'line_uid': 'e8608705a4116f6abda240bb',
#    'pair_line_uid': 'a4d2e449410a5ef31ce999c0',
#    'stops': [{'is_practical': 1,
#      'name': '虹桥火车站',
#      'uid': 'b18e5760f30d0afcd22dd648',
#      'x': 13506307.63,
#      'y': 3636462.03},
#     {'is_practical': 1,
#      'name': '诸光路',
#      'uid': '738eb570e6c64e42a7c7561f',
#      'x': 13503161.15,
#      'y': 3636137.25},
#     {'is_practical': 1,
#      'name': '蟠龙路',
#      'uid': '65467784060419d3018972ad',
#      'x': 13501643.81,
#      'y': 3635486.11},
#     {'is_practical': 0,
#      'name': '徐盈路',
#      'uid': '899927500668f3a3f33cba17',
#      'x': 13498883.73,
#      'y': 3634351.75},
#     {'is_practical': 1,
#      'name': '徐泾北城',
#      'uid': '83ef371b415b7a739cf77914',
#      'x': 13497453.88,
#      'y': 3633986.91},
#     {'is_practical': 0,
#      'name': '嘉松中路',
#      'uid': '29948fa82f67228714c8f6c6',
#      'x': 13495554.26,
#      'y': 3632529.51},
#     {'is_practical': 0,
#      'name': '赵巷',
#      'uid': '9b041634e34fbd97c37da2b9',
#      'x': 13491926.87,
#      'y': 3632197.89},
#     {'is_practical': 0,
#      'name': '汇金路',
#      'uid': '3cd492f93c2b1118d23ce35e',
#      'x': 13487430.89,
#      'y': 3632131.84},
#     {'is_practical': 1,
#      'name': '青浦新城',
#      'uid': 'c1fbafe00c30c2b2ae04575b',
#      'x': 13484465.59,
#      'y': 3631818.32},
#     {'is_practical': 1,
#      'name': '漕盈路',
#      'uid': 'eb9f75c542fb7f18a9175a58',
#      'x': 13481238.75,
#      'y': 3632094.12},
#     {'is_practical': 1,
#      'name': '淀山湖大道',
#      'uid': 'e3cfbbdbf3f8ce6e2fb9081c',
#      'x': 13479660.94,
#      'y': 3628741.88},
#     {'is_practical': 1,
#      'name': '朱家角',
#      'uid': 'd7ec1dc2906f13547bf79661',
#      'x': 13476118.31,
#      'y': 3624376.58},
#     {'is_practical': 0,
#      'name': '东方绿舟',
#      'uid': '8beb567c89c8aa1db5f42ffe',
#      'x': 13472730.81,
#      'y': 3624008.81}]},
#   {'line_name': '轨道交通浦江线(汇臻路-沈杜公路)',
#    'line_uid': '92cb003116315e68b817e788',
#    'pair_line_uid': 'dad6fd43605318301ce999f0',
#    'stops': [{'is_practical': 0,
#      'name': '汇臻路',
#      'uid': 'a7f00d8bb6a7b0cf6f476034',
#      'x': 13528959.92,
#      'y': 3614567.81},
#     {'is_practical': 0,
#      'name': '东城一路',
#      'uid': '1dbc9cdd63af51d6902ca316',
#      'x': 13529779.9,
#      'y': 3615194.9},
#     {'is_practical': 1,
#      'name': '浦航路',
#      'uid': 'fb4447a360507e4008ccdd38',
#      'x': 13529594.23,
#      'y': 3616620.46},
#     {'is_practical': 0,
#      'name': '闵瑞路',
#      'uid': '3f42162933c82b7282288a05',
#      'x': 13529569.91,
#      'y': 3617580.82},
#     {'is_practical': 0,
#      'name': '三鲁公路',
#      'uid': 'e690b106cb8f3bf001294f9d',
#      'x': 13529190.67,
#      'y': 3618558.73},
#     {'is_practical': 0,
#      'name': '沈杜公路',
#      'uid': '8b3282dab4193adde215f923',
#      'x': 13527567.82,
#      'y': 3619208.73}]}],
#  'result': {'ccode': '289', 'qt': 'bsi'}}

# %%
railway_json
# Out:
# {'content': [{'alias': ' ',
#    'company': '上海地铁运营有限公司',
#    'endTime': '22:10',
#    'end_index': 5,
#    'geo': '2|13527567.82,3614561.02;13529842.82,3619208.73|13528959.92,3614567.81,13529654.15,3614561.02,13529750.69,3614562.63,13529784.47,3614567.45,13529813.45,3614583.54,13529831.56,3614624.59,13529842.82,3614680.09,13529834.24,3614771.49,13529779.90,3615194.90,13529779.90,3615194.90,13529650.58,3616093.66,13529605.25,3616472.45,13529594.23,3616620.46,13529594.23,3616620.46,13529577.36,3616911.20,13529575.60,3617251.23,13529569.91,3617580.82,13529569.91,3617580.82,13529567.98,3617734.39,13529531.23,3618004.01,13529509.11,3618144.79,13529491.40,3618238.65,13529457.74,3618352.88,13529419.66,3618499.42,13529409.49,3618535.27,13529397.42,3618553.99,13529385.24,3618560.41,13529370.97,3618563.61,13529265.37,3618564.21,13529190.67,3618558.73,13529190.67,3618558.73,13529117.86,3618553.33,13529075.34,3618544.92,13528794.41,3618465.01,13528433.13,3618332.18,13528149.75,3618263.12,13527966.45,3618274.15,13527815.16,3618310.56,13527671.85,3618370.82,13527633.22,3618412.75,13527613.10,3618457.81,13527599.44,3618505.28,13527567.82,3619208.73,13527567.82,3619208.73;',
#    'headway': '约4-10分钟\\/趟',
#    'image': '',
#    'isMonTicket': 0,
#    'is_display': 0,
#    'kind': 512,
#    'kindtype': 512,
#    'line_color': '#9ba0ad',
#    'line_direction': '沈杜公路方向',
#    'maxPrice': 400,
#    'name': '轨道交通浦江线(汇臻路-沈杜公路)',
#    'nearest_station_idx': -1,
#    'pair_line': {'direction': '汇臻路方向',
#     'endTime': '22:30',
#     'kindtype': 512,
#     'name': '轨道交通浦江线(沈杜公路-汇臻路)',
#     'startTime': '06:00',
#     'uid': 'dad6fd43605318301ce999f0'},
#    'run_state': 0,
#    'startTime': '05:40',
#    'start_index': 0,
#    'stations': [{'geo': '1|13528959.92,3614567.81;13528959.92,3614567.81|13528959.92,3614567.81;',
#      'name': '汇臻路',
#      'operation_times': [{'end_station_name': '沈杜公路',
#        'end_time': '22:10',
#        'start_time': '05:40'}],
#      'pre_open': 0,
#      'rt_info': None,
#      'tri_rt_info': None,
#      'uid': 'a7f00d8bb6a7b0cf6f476034'},
#     {'geo': '1|13529779.90,3615194.90;13529779.90,3615194.90|13529779.90,3615194.90;',
#      'name': '东城一路',
#      'operation_times': [{'end_station_name': '沈杜公路',
#        'end_time': '22:12',
#        'start_time': '05:42'}],
#      'pre_open': 0,
#      'rt_info': None,
#      'tri_rt_info': None,
#      'uid': '1dbc9cdd63af51d6902ca316'},
#     {'geo': '1|13529594.23,3616620.46;13529594.23,3616620.46|13529594.23,3616620.46;',
#      'name': '浦航路',
#      'operation_times': [{'end_station_name': '沈杜公路',
#        'end_time': '22:14',
#        'start_time': '05:44'}],
#      'pre_open': 0,
#      'rt_info': None,
#      'tri_rt_info': None,
#      'uid': 'fb4447a360507e4008ccdd38'},
#     {'geo': '1|13529569.91,3617580.82;13529569.91,3617580.82|13529569.91,3617580.82;',
#      'name': '闵瑞路',
#      'operation_times': [{'end_station_name': '沈杜公路',
#        'end_time': '22:16',
#        'start_time': '05:46'}],
#      'pre_open': 0,
#      'rt_info': None,
#      'tri_rt_info': None,
#      'uid': '3f42162933c82b7282288a05'},
#     {'geo': '1|13529190.67,3618558.73;13529190.67,3618558.73|13529190.67,3618558.73;',
#      'name': '三鲁公路',
#      'operation_times': [{'end_station_name': '沈杜公路',
#        'end_time': '22:18',
#        'start_time': '05:48'}],
#      'pre_open': 0,
#      'rt_info': None,
#      'tri_rt_info': None,
#      'uid': 'e690b106cb8f3bf001294f9d'},
#     {'geo': '1|13527567.82,3619208.73;13527567.82,3619208.73|13527567.82,3619208.73;',
#      'name': '沈杜公路',
#      'pre_open': 0,
#      'rt_info': None,
#      'subways': [{'background_color': '#0066cc',
#        'name': '<font color="#ffffff">8号线<\\/font>'}],
#      'transfer': [[{'name': '地铁8号线(沈杜公路-市光路)',
#         'uid': '453b2d228cf08f16d4851fb7'}]],
#      'tri_rt_info': None,
#      'uid': '8b3282dab4193adde215f923'}],
#    'ticketPrice': 300,
#    'ticket_price_ext': '',
#    'timetable': '周一至周五 05:40-22:10  周六日 05:40-22:10  ',
#    'timetable_ext': '',
#    'uid': '92cb003116315e68b817e788',
#    'workTime': [],
#    'workingTimeDesc': [],
#    'lineColor': '#9ba0ad'}],
#  'current_city': {'code': 289,
#   'geo': '1|13523265.31,3641114.64;13523265.31,3641114.64|13523265.31,3641114.64;',
#   'level': 12,
#   'name': '上海市',
#   'sgeo': [13523265, 3641114],
#   'sup': 1,
#   'sup_bus': 1,
#   'sup_business_area': 1,
#   'sup_lukuang': 1,
#   'sup_subway': 1,
#   'type': 2,
#   'up_province_name': '上海市'},
#  'hot_city': ['北京市|131',
#   '上海市|289',
#   '广州市|257',
#   '深圳市|340',
#   '成都市|75',
#   '天津市|332',
#   '南京市|315',
#   '杭州市|179',
#   '武汉市|218',
#   '重庆市|132'],
#  'result': {'count': 1,
#   'error': 0,
#   'is_subway': 1,
#   'linetype': 1,
#   'qid': '7727632442422997370',
#   'time': 0,
#   'total': 1,
#   'type': 18,
#   'uii_type': 'china_main',
#   'region': '0',
#   'uii_qt': 'bsl',
#   'login_debug': 0}}

# %%
import numpy as np
import math

PI = math.pi

def _transformlat(coordinates):
    lng = coordinates[ : , 0] - 105
    lat = coordinates[ : , 1] - 35
    ret = -100 + 2 * lng + 3 * lat + 0.2 * lat * lat + \
          0.1 * lng * lat + 0.2 * np.sqrt(np.fabs(lng))
    ret += (20 * np.sin(6 * lng * PI) + 20 *
            np.sin(2 * lng * PI)) * 2 / 3
    ret += (20 * np.sin(lat * PI) + 40 *
            np.sin(lat / 3 * PI)) * 2 / 3
    ret += (160 * np.sin(lat / 12 * PI) + 320 *
            np.sin(lat * PI / 30.0)) * 2 / 3
    return ret


def _transformlng(coordinates):
    lng = coordinates[ : , 0] - 105
    lat = coordinates[ : , 1] - 35
    ret = 300 + lng + 2 * lat + 0.1 * lng * lng + \
          0.1 * lng * lat + 0.1 * np.sqrt(np.fabs(lng))
    ret += (20 * np.sin(6 * lng * PI) + 20 *
            np.sin(2 * lng * PI)) * 2 / 3
    ret += (20 * np.sin(lng * PI) + 40 *
            np.sin(lng / 3 * PI)) * 2 / 3
    ret += (150 * np.sin(lng / 12 * PI) + 300 *
            np.sin(lng / 30 * PI)) * 2 / 3
    return ret


def gcj02_to_wgs84(coordinates):
    """
    GCJ-02转WGS-84
    :param coordinates: GCJ-02坐标系的经度和纬度的numpy数组
    :returns: WGS-84坐标系的经度和纬度的numpy数组
    """
    ee = 0.006693421622965943  # 偏心率平方
    a = 6378245  # 长半轴
    lng = coordinates[ : , 0]
    lat = coordinates[ : , 1]
    is_in_china= (lng > 73.66) & (lng < 135.05) & (lat > 3.86) & (lat < 53.55)
    _transform = coordinates[is_in_china]  #只对国内的坐标做偏移
    
    dlat = _transformlat(_transform)
    dlng = _transformlng(_transform)
    radlat = _transform[ : , 1] / 180 * PI
    magic = np.sin(radlat)
    magic = 1 - ee * magic * magic
    sqrtmagic = np.sqrt(magic)
    dlat = (dlat * 180.0) / ((a * (1 - ee)) / (magic * sqrtmagic) * PI)
    dlng = (dlng * 180.0) / (a / sqrtmagic * np.cos(radlat) * PI)
    mglat = _transform[ : , 1] + dlat
    mglng = _transform[ : , 0] + dlng
    coordinates[is_in_china] = np.array([
        _transform[ : , 0] * 2 - mglng, _transform[ : , 1] * 2 - mglat
    ]).T
    return coordinates


def bd09_to_gcj02(coordinates):
    """
    BD-09转GCJ-02
    :param coordinates: BD-09坐标系的经度和纬度的numpy数组
    :returns: GCJ-02坐标系的经度和纬度的numpy数组
    """
    x_pi = PI * 3000 / 180
    x = coordinates[ : , 0] - 0.0065
    y = coordinates[ : , 1] - 0.006
    z = np.sqrt(x * x + y * y) - 0.00002 * np.sin(y * x_pi)
    theta = np.arctan2(y, x) - 0.000003 * np.cos(x * x_pi)
    lng = z * np.cos(theta)
    lat = z * np.sin(theta)
    coordinates = np.array([lng, lat]).T
    return coordinates


def bd09_to_wgs84(coordinates):
    """
    BD-09转WGS-84
    :param coordinates: BD-09坐标系的经度和纬度的numpy数组
    :returns: WGS-84坐标系的经度和纬度的numpy数组
    """
    return gcj02_to_wgs84(bd09_to_gcj02(coordinates))


def mercator_to_bd09(mercator):
    """
    墨卡托转BD-09
    :param coordinates: GCJ-02坐标系的经度和纬度的numpy数组
    :returns: WGS-84坐标系的经度和纬度的numpy数组
    """
    MCBAND = [12890594.86, 8362377.87, 5591021, 3481989.83, 1678043.12, 0]
    MC2LL = [[1.410526172116255e-08,   8.98305509648872e-06,    -1.9939833816331,        
              200.9824383106796,       -187.2403703815547,      91.6087516669843,
              -23.38765649603339,      2.57121317296198,        -0.03801003308653,
              17337981.2],
            [-7.435856389565537e-09,  8.983055097726239e-06,   -0.78625201886289,
             96.32687599759846,       -1.85204757529826,       -59.36935905485877,
             47.40033549296737,       -16.50741931063887,      2.28786674699375,
             10260144.86],
            [-3.030883460898826e-08,  8.98305509983578e-06,    0.30071316287616,
             59.74293618442277,       7.357984074871,          -25.38371002664745,
             13.45380521110908,       -3.29883767235584,       0.32710905363475,
             6856817.37],
            [-1.981981304930552e-08,  8.983055099779535e-06,   0.03278182852591,
             40.31678527705744,       0.65659298677277,        -4.44255534477492,
             0.85341911805263,        0.12923347998204,        -0.04625736007561,
             4482777.06], 
            [3.09191371068437e-09,    8.983055096812155e-06,   6.995724062e-05,
             23.10934304144901,       -0.00023663490511,       -0.6321817810242,
             -0.00663494467273,       0.03430082397953,        -0.00466043876332,
             2555164.4],  
            [2.890871144776878e-09,   8.983055095805407e-06,   -3.068298e-08,
             7.47137025468032,        -3.53937994e-06,         -0.02145144861037,
             -1.234426596e-05,        0.00010322952773,        -3.23890364e-06,
             826088.5]] 
    
    x = np.abs(mercator[ : , 0])
    y = np.abs(mercator[ : , 1])
    coef = np.array([
           MC2LL[index] for index in 
           (np.tile(y.reshape((-1, 1)), (1, 6)) < MCBAND).sum(axis=1)
    ])   
    return converter(x, y, coef)


def converter(x, y, coef):
    x_temp = coef[ : ,0] + coef[ : ,1] * np.abs(x)
    x_n = np.abs(y) / coef[ : ,9]
    y_temp = coef[ : ,2] + coef[ : ,3] * x_n + coef[ : ,4] * x_n ** 2 + \
             coef[ : ,5] * x_n ** 3 + coef[ : ,6] * x_n ** 4 + coef[ : ,7] * x_n ** 5 + \
             coef[ : ,8] * x_n ** 6
    x[x < 0] = -1
    x[x >= 0] = 1
    y[y < 0] = -1
    y[y >= 0] = 1    
    x_temp *= x
    y_temp *= y
    coordinates = np.array([x_temp, y_temp]).T
    return coordinates
trace_mercator = np.array(
        # 取出线路信息字典，以“|”划分后，取出第三部分信息，去掉末尾的“;”,获取墨卡托坐标序列
        railway_json['content'][0]['geo'].split('|')[2][ : -1].split(','), 
        dtype=float
    ).reshape((-1, 2)) 
trace_coordinates = bd09_to_wgs84(mercator_to_bd09(trace_mercator))

# %%
import plotly.offline as py
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode

init_notebook_mode(connected=True) #如果使用jupyter需要加上这一句，把地图显示在页面上

mapbox_access_token = '''
pk.eyJ1IjoibHVrYXNtYXJ0aW5lbGxpIiwiYSI6ImNpem85dmhwazAyajIyd284dGxhN2VxYnYifQ.HQCmyhEXZUTz3S98FMrVAQ
'''
layout = go.Layout(
    #autosize=True,
    mapbox=dict(
        accesstoken=mapbox_access_token,
        center=dict(
            lat=23.12864583, #广州市纬度
            lon= 113.2648325 #广州市经度
        ),
        pitch=0,
        zoom=10,
    ),
   autosize=False,width=900,height=600,#设置图像的大小
)

color = ('blue', 'green', 'yellow', 'purple', 'orange', 'red', 'violet', 
        'navy', 'crimson', 'cyan', 'magenta', 'maroon', 'peru') #可按需增加
data = [] #绘制数据
marked = set()
cnt = 0
for line in station_info_json['content']:
    uid = line['line_uid']
    if uid in marked: #由于线路包括了来回两个方向，需要排除已绘制线路的反向线路
        continue
        
    plots = [] #站台墨卡托坐标
    plots_name = [] #站台名称
    for plot in line['stops']:
        plots.append([plot['x'], plot['y']])
        plots_name.append(plot['name'])
    plot_mercator = np.array(plots)
    plot_coordinates = bd09_to_wgs84(mercator_to_bd09(plot_mercator)) #站台经纬度

    data.append(
        go.Scattermapbox(
            lon=plot_coordinates[:, 0], #站台经度
            lat=plot_coordinates[:, 1], #站台纬度
            mode='markers+lines',
            name=line['line_name'], #线路名称，显示在图例（legend）上
            text=plots_name, #各个点的名称，鼠标悬浮在点上时显示
            # 设置标记点的参数
            marker=go.scattermapbox.Marker(
                size=10,
                color=color[cnt]
            ),
        )
    )
    marked.add(uid) #添加已绘制线路的uid
    marked.add(line['pair_line_uid']) #添加已绘制线路反向线路的uid
    cnt = (cnt + 1) % len(color)

fig = dict(data=data, layout=layout)
#py.iplot(fig) #直接显示地图

py.plot(fig, filename='Guangzhou_railway.html') #生成html文件并打开
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 'Guangzhou_railway.html'
